# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df = pd.read_csv('heroes_information.csv')

heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Your code here
heroes_df = pd.read_csv('heroes_information.csv',index_col=0)

heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == ['name', 'Gender', 'Eye color', 'Race',
 'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight']

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 63.1+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
Most of the rows and columns show that the data is relatively clean with 734 values.
The missing values are shown in columns 6: Publisher & 9: Weight
"""
# Out:
# '\nMost of the rows and columns show that the data is relatively clean with 734 values.\nThe missing values are shown in columns 6: Publisher & 9: Weight\n'

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv',index_col=0)
powers_df.head()
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
#
#                        Agent Bob  Agent Zero  Air-Walker   Ajax  Alan Scott  \
# Agility                    False       False       False   True       False
# Accelerated Healing        False       False       False  False       False
# Lantern Power Ring         False       False       False  False       False
# Dimensional Awareness      False       False       False  False       False
# Cold Resistance            False       False       False  False       False
#
#                        Alex Mercer  Alex Woolsly  Alien  Allan Quatermain  \
# Agility                       True         False   True             False
# Accelerated Healing           True         False  False             False
# Lantern Power Ring           False         False  False             False
# Dimensional Awareness        False         False  False             False
# Cold Resistance              False         False   True             False
#
#                        Amazo   Ammo  Ando Masahashi  Angel  Angel Dust  \
# Agility                 True  False           False   True        True
# Accelerated Healing    False  False           False   True       False
# Lantern Power Ring      True  False           False  False       False
# Dimensional Awareness  False  False           False  False       False
# Cold Resistance        False  False           False  False       False
#
#                        Angel Salvadore  Angela  Animal Man  Annihilus  \
# Agility                          False   False       False       True
# Accelerated Healing              False   False       False      False
# Lantern Power Ring               False   False       False      False
# Dimensional Awareness            False   False       False      False
# Cold Resistance                  False   False       False      False
#
#                        Ant-Man  Ant-Man II  Anti-Monitor  Anti-Spawn  \
# Agility                  False        True         False       False
# Accelerated Healing      False       False          True       False
# Lantern Power Ring       False       False         False       False
# Dimensional Awareness    False       False          True       False
# Cold Resistance          False       False         False       False
#
#                        Anti-Venom  Apocalypse  Aquababy  Aqualad  Aquaman  \
# Agility                     False        True     False    False     True
# Accelerated Healing          True        True     False    False     True
# Lantern Power Ring          False       False     False    False    False
# Dimensional Awareness       False       False     False    False    False
# Cold Resistance             False       False     False    False     True
#
#                        Arachne  Archangel  Arclight  Ardina   Ares  Ariel  \
# Agility                   True       True     False    True   True  False
# Accelerated Healing       True       True     False    True   True  False
# Lantern Power Ring       False      False     False   False  False  False
# Dimensional Awareness    False      False     False   False  False  False
# Cold Resistance          False      False     False    True  False  False
#
#                        Armor  Astro Boy  Atlas   Atom  Atom Girl  Atom II  \
# Agility                False      False  False  False      False    False
# Accelerated Healing    False      False  False  False      False    False
# Lantern Power Ring     False      False  False  False      False    False
# Dimensional Awareness  False      False  False  False      False    False
# Cold Resistance        False      False  False  False      False    False
#
#                        Atom III  Atom IV  Aurora  Azazel  Azrael  Aztar  \
# Agility                   False    False   False   False   False  False
# Accelerated Healing       False    False    True    True   False  False
# Lantern Power Ring        False    False   False   False   False  False
# Dimensional Awareness     False    False   False   False   False  False
# Cold Resistance           False    False   False   False   False  False
#
#                        Bananaman   Bane  Banshee  Bantam  Batgirl  Batgirl IV  \
# Agility                    False  False    False   False    False        True
# Accelerated Healing        False  False    False   False    False       False
# Lantern Power Ring         False  False    False   False    False       False
# Dimensional Awareness      False  False    False   False    False       False
# Cold Resistance            False  False    False   False    False       False
#
#                        Batgirl VI  Batman  Batman II  Battlestar  Batwoman V  \
# Agility                      True    True       True        True       False
# Accelerated Healing         False   False      False       False       False
# Lantern Power Ring          False   False      False       False       False
# Dimensional Awareness       False   False      False       False       False
# Cold Resistance             False   False      False       False       False
#
#                         Beak  Beast  Beast Boy  Ben 10  Beta Ray Bill  \
# Agility                False   True       True   False          False
# Accelerated Healing    False   True      False   False           True
# Lantern Power Ring     False  False      False   False          False
# Dimensional Awareness  False  False      False   False          False
# Cold Resistance        False  False      False   False          False
#
#                        Beyonder  Big Barda  Big Daddy  Big Man  Bill Harken  \
# Agility                   False       True      False    False        False
# Accelerated Healing        True      False      False    False        False
# Lantern Power Ring        False      False      False    False        False
# Dimensional Awareness      True      False      False    False        False
# Cold Resistance           False      False      False    False        False
#
#                        Billy Kincaid  Binary  Bionic Woman  Bird-Brain  \
# Agility                        False   False          True       False
# Accelerated Healing            False   False         False       False
# Lantern Power Ring             False   False         False       False
# Dimensional Awareness          False   False         False       False
# Cold Resistance                False   False         False       False
#
#                        Bird-Man  Bird-Man II  Birdman  Bishop  Bizarro  \
# Agility                   False        False     True   False     True
# Accelerated Healing       False        False    False    True     True
# Lantern Power Ring        False        False    False   False    False
# Dimensional Awareness     False        False    False   False    False
# Cold Resistance           False        False    False   False    False
#
#                        Bizarro-Girl  Black Abbott  Black Adam  Black Bolt  \
# Agility                        True         False       False        True
# Accelerated Healing            True         False        True       False
# Lantern Power Ring            False         False       False       False
# Dimensional Awareness         False         False       False       False
# Cold Resistance               False         False       False       False
#
#                        Black Canary  Black Cat  Black Flash  Black Knight III  \
# Agility                        True       True         True             False
# Accelerated Healing           False      False        False             False
# Lantern Power Ring            False      False        False             False
# Dimensional Awareness         False      False        False             False
# Cold Resistance               False      False        False             False
#
#                        Black Lightning  Black Mamba  Black Manta  \
# Agility                          False        False         True
# Accelerated Healing              False        False        False
# Lantern Power Ring               False        False        False
# Dimensional Awareness            False        False        False
# Cold Resistance                  False        False         True
#
#                        Black Panther  Black Vulcan  Black Widow  Blackout  \
# Agility                         True         False         True      True
# Accelerated Healing            False         False        False      True
# Lantern Power Ring             False         False        False     False
# Dimensional Awareness          False         False        False     False
# Cold Resistance                False         False        False     False
#
#                        Blackwing  Blackwulf  Blade  Bling!  Blink  Blizzard  \
# Agility                    False      False   True   False  False     False
# Accelerated Healing        False      False   True   False  False     False
# Lantern Power Ring         False      False  False   False  False     False
# Dimensional Awareness      False      False  False   False  False     False
# Cold Resistance            False      False  False   False  False     False
#
#                        Blizzard II   Blob  Bloodaxe  Bloodhawk  Bloodwraith  \
# Agility                      False  False      True      False        False
# Accelerated Healing          False  False     False      False        False
# Lantern Power Ring           False  False     False      False        False
# Dimensional Awareness        False  False     False      False        False
# Cold Resistance              False  False     False      False        False
#
#                        Blue Beetle  Blue Beetle II  Blue Beetle III  \
# Agility                      False           False             True
# Accelerated Healing          False           False             True
# Lantern Power Ring           False           False            False
# Dimensional Awareness        False           False            False
# Cold Resistance              False           False             True
#
#                        Blue Streak  Boba Fett  Bomb Queen  Boom-Boom  \
# Agility                      False       True       False       True
# Accelerated Healing           True      False        True      False
# Lantern Power Ring           False      False       False      False
# Dimensional Awareness        False      False       False      False
# Cold Resistance              False      False       False      False
#
#                        Booster Gold  Box IV  Bradley  Brainiac  Brainiac 5  \
# Agility                        True   False    False     False       False
# Accelerated Healing           False   False    False     False       False
# Lantern Power Ring            False   False    False     False       False
# Dimensional Awareness         False   False    False     False       False
# Cold Resistance               False   False    False     False       False
#
#                        Brother Voodoo  Brundlefly  Buffy  Bullseye  Bumblebee  \
# Agility                         False        True   True     False      False
# Accelerated Healing             False       False   True     False      False
# Lantern Power Ring              False       False  False     False      False
# Dimensional Awareness           False       False  False     False      False
# Cold Resistance                 False       False  False     False      False
#
#                        Bumbleboy  Bushido  Cable  Callisto  Cameron Hicks  \
# Agility                    False     True   True      True          False
# Accelerated Healing        False    False   True      True          False
# Lantern Power Ring         False    False  False     False          False
# Dimensional Awareness      False    False  False     False          False
# Cold Resistance            False    False  False     False          False
#
#                        Cannonball  Captain America  Captain Atom  \
# Agility                     False             True          True
# Accelerated Healing         False            False          True
# Lantern Power Ring          False            False         False
# Dimensional Awareness       False            False         False
# Cold Resistance             False            False         False
#
#                        Captain Britain  Captain Cold  Captain Epic  \
# Agility                           True         False         False
# Accelerated Healing              False         False         False
# Lantern Power Ring               False         False         False
# Dimensional Awareness            False         False         False
# Cold Resistance                  False         False         False
#
#                        Captain Hindsight  Captain Marvel  Captain Marvel II  \
# Agility                            False            True              False
# Accelerated Healing                False            True              False
# Lantern Power Ring                 False           False              False
# Dimensional Awareness              False           False              False
# Cold Resistance                    False            True              False
#
#                        Captain Midnight  Captain Planet  Captain Universe  \
# Agility                           False           False             False
# Accelerated Healing               False           False             False
# Lantern Power Ring                False           False             False
# Dimensional Awareness             False           False             False
# Cold Resistance                   False           False              True
#
#                        Carnage    Cat  Catwoman  Century  Cerebra  Chamber  \
# Agility                   True   True      True    False    False    False
# Accelerated Healing       True  False     False    False    False    False
# Lantern Power Ring       False  False     False    False    False    False
# Dimensional Awareness    False  False     False    False    False    False
# Cold Resistance          False  False     False    False    False    False
#
#                        Chameleon  Changeling  Cheetah  Cheetah II  \
# Agility                    False       False     True        True
# Accelerated Healing        False       False    False       False
# Lantern Power Ring         False       False    False       False
# Dimensional Awareness      False       False    False       False
# Cold Resistance            False       False    False       False
#
#                        Cheetah III  Chromos  Chuck Norris  Citizen Steel  \
# Agility                       True     True         False           True
# Accelerated Healing          False    False         False          False
# Lantern Power Ring           False    False         False          False
# Dimensional Awareness        False    False         False          False
# Cold Resistance              False    False         False          False
#
#                        Claire Bennet  Clayface  Cloak  Cogliostro  Colossus  \
# Agility                        False      True  False       False     False
# Accelerated Healing             True     False  False       False     False
# Lantern Power Ring             False     False  False       False     False
# Dimensional Awareness          False     False   True       False     False
# Cold Resistance                False     False  False       False      True
#
#                        Concrete  Copycat  Cottonmouth  Crimson Crusader  \
# Agility                   False    False        False             False
# Accelerated Healing       False    False        False             False
# Lantern Power Ring        False    False        False             False
# Dimensional Awareness     False    False        False             False
# Cold Resistance           False    False        False             False
#
#                        Crimson Dynamo  Crystal  Curse  Cy-Gor  Cyborg  \
# Agility                         False    False  False   False   False
# Accelerated Healing             False    False  False   False   False
# Lantern Power Ring              False    False  False   False   False
# Dimensional Awareness           False    False  False   False   False
# Cold Resistance                 False    False  False   False   False
#
#                        Cyborg Superman  Cyclops  DL Hawkins  Dagger  \
# Agility                          False     True       False   False
# Accelerated Healing              False    False       False   False
# Lantern Power Ring               False    False       False   False
# Dimensional Awareness            False    False       False   False
# Cold Resistance                  False    False       False   False
#
#                        Daphne Powell  Daredevil  Darkhawk  Darkman  Darkseid  \
# Agility                        False       True     False    False      True
# Accelerated Healing            False      False     False    False      True
# Lantern Power Ring             False      False     False    False     False
# Dimensional Awareness          False      False     False    False      True
# Cold Resistance                False      False     False    False     False
#
#                        Darkstar  Darth Maul  Darth Vader   Dash   Data  \
# Agility                   False        True         True   True   True
# Accelerated Healing       False       False         True  False  False
# Lantern Power Ring        False       False        False  False  False
# Dimensional Awareness     False       False        False  False  False
# Cold Resistance           False       False        False  False   True
#
#                        Dazzler  Deadman  Deadpool  Deadshot  Deathlok  \
# Agility                   True     True      True     False      True
# Accelerated Healing      False    False      True     False     False
# Lantern Power Ring       False     True     False     False     False
# Dimensional Awareness    False    False      True     False     False
# Cold Resistance          False    False     False     False     False
#
#                        Deathstroke  Dementor  Demogoblin  Destroyer  \
# Agility                       True      True        True      False
# Accelerated Healing           True     False       False      False
# Lantern Power Ring           False     False       False      False
# Dimensional Awareness        False     False       False      False
# Cold Resistance              False     False       False      False
#
#                        Diamondback  Doc Samson  Doctor Doom  Doctor Doom II  \
# Agility                      False       False        False           False
# Accelerated Healing          False       False        False           False
# Lantern Power Ring           False       False        False           False
# Dimensional Awareness        False       False        False           False
# Cold Resistance              False       False        False           False
#
#                        Doctor Fate  Doctor Octopus  Doctor Poison  \
# Agility                      False            True          False
# Accelerated Healing           True           False          False
# Lantern Power Ring           False           False          False
# Dimensional Awareness         True           False          False
# Cold Resistance              False           False          False
#
#                        Doctor Strange  Domino  Donatello  Donna Troy  \
# Agility                         False    True       True       False
# Accelerated Healing             False   False       True       False
# Lantern Power Ring              False   False      False       False
# Dimensional Awareness            True   False      False       False
# Cold Resistance                 False   False      False       False
#
#                        Doomsday  Doppelganger  Dormammu  Dr Manhattan  \
# Agility                    True          True     False         False
# Accelerated Healing        True          True     False          True
# Lantern Power Ring        False         False     False         False
# Dimensional Awareness     False         False     False         False
# Cold Resistance            True         False     False         False
#
#                        Drax the Destroyer    Ego  Elastigirl  Electro  \
# Agility                              True  False        True    False
# Accelerated Healing                  True  False       False    False
# Lantern Power Ring                  False  False       False    False
# Dimensional Awareness               False  False       False    False
# Cold Resistance                      True  False       False    False
#
#                        Elektra  Elle Bishop  Elongated Man  Emma Frost  \
# Agility                   True        False           True       False
# Accelerated Healing      False        False          False       False
# Lantern Power Ring       False        False          False       False
# Dimensional Awareness    False        False          False       False
# Cold Resistance          False        False          False       False
#
#                        Enchantress  Energy  Ethan Hunt  Etrigan  \
# Agility                      False   False        True    False
# Accelerated Healing           True   False       False     True
# Lantern Power Ring           False   False       False    False
# Dimensional Awareness        False   False       False    False
# Cold Resistance              False   False       False    False
#
#                        Evil Deadpool  Evilhawk  Exodus  Fabian Cortez  Falcon  \
# Agility                         True     False   False          False   False
# Accelerated Healing             True      True    True          False   False
# Lantern Power Ring             False     False   False          False   False
# Dimensional Awareness           True     False   False          False   False
# Cold Resistance                False     False   False          False   False
#
#                        Fallen One II  Faora  Feral  Fighting Spirit  \
# Agility                        False  False   True            False
# Accelerated Healing             True   True   True            False
# Lantern Power Ring             False  False  False            False
# Dimensional Awareness          False  False  False            False
# Cold Resistance                False  False  False            False
#
#                        Fin Fang Foom   Fire  Firebird  Firelord  Firestar  \
# Agility                        False  False     False     False     False
# Accelerated Healing             True  False     False     False     False
# Lantern Power Ring             False  False     False     False     False
# Dimensional Awareness          False  False     False     False     False
# Cold Resistance                False  False     False     False     False
#
#                        Firestorm  Flash  Flash Gordon  Flash II  Flash III  \
# Agility                    False  False         False      True      False
# Accelerated Healing        False   True         False      True       True
# Lantern Power Ring         False  False         False     False      False
# Dimensional Awareness      False  False         False     False      False
# Cold Resistance            False  False         False     False      False
#
#                        Flash IV  Forge  Franklin Richards  Frenzy  Frigga  \
# Agility                   False  False               True   False   False
# Accelerated Healing        True  False              False   False   False
# Lantern Power Ring        False  False              False   False   False
# Dimensional Awareness     False  False               True   False   False
# Cold Resistance           False  False              False    True   False
#
#                        Galactus  Gambit  Gamora  Garbage Man  Gary Bell  \
# Agility                   False    True    True        False      False
# Accelerated Healing        True   False    True         True      False
# Lantern Power Ring        False   False   False        False      False
# Dimensional Awareness      True   False   False        False      False
# Cold Resistance           False   False   False        False      False
#
#                        General Zod  Genesis  Ghost Rider  Ghost Rider II  \
# Agility                      False    False         True           False
# Accelerated Healing           True    False         True           False
# Lantern Power Ring           False    False        False           False
# Dimensional Awareness        False    False        False           False
# Cold Resistance              False    False        False           False
#
#                        Giganta  Gladiator  Goblin Queen  Godzilla    Gog  \
# Agility                  False       True         False      True   True
# Accelerated Healing      False       True         False     False  False
# Lantern Power Ring       False      False         False     False  False
# Dimensional Awareness    False      False         False     False  False
# Cold Resistance          False      False         False     False  False
#
#                         Goku  Goliath IV  Gorilla Grodd  Granny Goodness  \
# Agility                 True       False           True            False
# Accelerated Healing     True       False          False            False
# Lantern Power Ring     False       False          False            False
# Dimensional Awareness  False       False          False            False
# Cold Resistance        False       False          False            False
#
#                        Gravity  Greedo  Green Arrow  Green Goblin  \
# Agility                  False   False         True          True
# Accelerated Healing      False   False        False          True
# Lantern Power Ring       False   False        False         False
# Dimensional Awareness    False   False        False         False
# Cold Resistance          False   False        False         False
#
#                        Green Goblin II  Green Goblin III  Green Goblin IV  \
# Agility                          False             False            False
# Accelerated Healing               True             False            False
# Lantern Power Ring               False             False            False
# Dimensional Awareness            False             False            False
# Cold Resistance                  False             False            False
#
#                        Groot  Guy Gardner  Hal Jordan  Han Solo  Hancock  \
# Agility                False        False        True      True     True
# Accelerated Healing    False        False       False     False     True
# Lantern Power Ring     False         True        True     False    False
# Dimensional Awareness  False        False       False     False    False
# Cold Resistance        False        False       False     False    False
#
#                        Harley Quinn  Harry Potter  Havok   Hawk  Hawkeye  \
# Agility                        True          True  False  False     True
# Accelerated Healing            True          True  False   True    False
# Lantern Power Ring            False         False  False  False    False
# Dimensional Awareness         False         False  False  False    False
# Cold Resistance               False         False  False  False    False
#
#                        Hawkeye II  Hawkgirl  Hawkman  Heat Wave   Hela  \
# Agility                     False     False    False      False   True
# Accelerated Healing         False      True    False      False   True
# Lantern Power Ring          False     False    False      False  False
# Dimensional Awareness       False     False    False      False  False
# Cold Resistance             False      True    False      False  False
#
#                        Hellboy  Hellcat  Hellgramite  Hellstorm  Hercules  \
# Agility                  False     True        False      False     False
# Accelerated Healing       True    False        False       True      True
# Lantern Power Ring       False    False        False      False     False
# Dimensional Awareness    False    False        False      False     False
# Cold Resistance          False    False        False      False     False
#
#                        Hiro Nakamura  Hit-Girl  Hobgoblin  Hollow  \
# Agility                        False      True      False   False
# Accelerated Healing            False     False      False   False
# Lantern Power Ring             False     False      False   False
# Dimensional Awareness          False     False      False   False
# Cold Resistance                False     False      False   False
#
#                        Hope Summers   Hulk  Human Torch  Huntress   Husk  \
# Agility                       False   True         True     False  False
# Accelerated Healing           False   True        False     False  False
# Lantern Power Ring            False  False        False     False  False
# Dimensional Awareness         False  False        False     False  False
# Cold Resistance               False   True        False     False  False
#
#                        Hybrid  Hydro-Man  Hyperion  Iceman  Impulse  \
# Agility                  True      False      True    True    False
# Accelerated Healing      True      False     False    True     True
# Lantern Power Ring      False      False     False   False    False
# Dimensional Awareness   False      False     False   False    False
# Cold Resistance         False      False     False    True    False
#
#                        Indiana Jones  Indigo    Ink  Invisible Woman  \
# Agility                        False   False  False            False
# Accelerated Healing            False   False   True            False
# Lantern Power Ring             False    True  False            False
# Dimensional Awareness          False   False  False            False
# Cold Resistance                False   False  False            False
#
#                        Iron Fist  Iron Man  Iron Monger   Isis  JJ Powell  \
# Agility                     True     False        False  False      False
# Accelerated Healing         True      True        False   True      False
# Lantern Power Ring         False     False        False  False      False
# Dimensional Awareness      False     False        False  False      False
# Cold Resistance             True     False        False  False      False
#
#                        Jack of Hearts  Jack-Jack  James Bond  James T. Kirk  \
# Agility                         False       True       False          False
# Accelerated Healing              True      False       False          False
# Lantern Power Ring              False      False       False          False
# Dimensional Awareness           False      False       False          False
# Cold Resistance                  True      False       False          False
#
#                        Jar Jar Binks  Jason Bourne  Jean Grey  \
# Agility                         True          True      False
# Accelerated Healing            False         False      False
# Lantern Power Ring             False         False      False
# Dimensional Awareness          False         False      False
# Cold Resistance                False         False      False
#
#                        Jean-Luc Picard  Jennifer Kale  Jessica Cruz  \
# Agility                          False          False          True
# Accelerated Healing              False          False         False
# Lantern Power Ring               False          False          True
# Dimensional Awareness            False          False         False
# Cold Resistance                  False          False         False
#
#                        Jessica Jones  Jim Powell  Johann Krauss  \
# Agility                        False       False          False
# Accelerated Healing            False       False          False
# Lantern Power Ring             False       False          False
# Dimensional Awareness          False       False          False
# Cold Resistance                False       False          False
#
#                        John Constantine  John Stewart  John Wraith  Joker  \
# Agility                           False         False        False  False
# Accelerated Healing                True         False        False  False
# Lantern Power Ring                False          True        False  False
# Dimensional Awareness             False         False        False  False
# Cold Resistance                   False         False        False  False
#
#                         Jolt  Jubilee  Judge Dredd  Juggernaut  Junkpile  \
# Agility                False    False         True       False     False
# Accelerated Healing    False    False        False        True     False
# Lantern Power Ring     False    False        False       False     False
# Dimensional Awareness  False    False        False       False     False
# Cold Resistance        False    False        False       False     False
#
#                        Justice  K-2SO   Kang  Karate Kid  Kathryn Janeway  \
# Agility                  False  False  False        True            False
# Accelerated Healing      False  False  False       False            False
# Lantern Power Ring       False  False  False       False            False
# Dimensional Awareness    False  False  False       False            False
# Cold Resistance          False  False  False       False            False
#
#                        Katniss Everdeen  Kevin 11  Kick-Ass  Kid Flash  \
# Agility                            True      True      True      False
# Accelerated Healing               False      True     False       True
# Lantern Power Ring                False     False     False      False
# Dimensional Awareness             False     False     False      False
# Cold Resistance                   False     False     False      False
#
#                        Killer Croc  Killer Frost  Kilowog  King Kong  \
# Agility                       True         False    False       True
# Accelerated Healing           True         False     True      False
# Lantern Power Ring           False         False     True      False
# Dimensional Awareness        False         False    False      False
# Cold Resistance              False          True    False      False
#
#                        King Shark   Klaw  Kool-Aid Man  Kraven II  \
# Agility                     False  False         False       True
# Accelerated Healing         False  False         False       True
# Lantern Power Ring          False  False         False      False
# Dimensional Awareness       False  False         False      False
# Cold Resistance              True  False         False      False
#
#                        Kraven the Hunter  Krypto  Kyle Rayner  Kylo Ren  \
# Agility                             True   False        False      True
# Accelerated Healing                False    True        False      True
# Lantern Power Ring                 False   False         True     False
# Dimensional Awareness              False   False        False     False
# Cold Resistance                    False   False        False     False
#
#                        Lady Bullseye  Lady Deathstrike  Lara Croft  Leader  \
# Agility                        False              True        True   False
# Accelerated Healing            False              True       False   False
# Lantern Power Ring             False             False       False   False
# Dimensional Awareness          False             False       False   False
# Cold Resistance                False             False       False   False
#
#                        Leech  Legion  Leonardo  Lex Luthor  Light Lass  \
# Agility                False    True      True       False       False
# Accelerated Healing    False    True      True       False       False
# Lantern Power Ring     False   False     False       False       False
# Dimensional Awareness  False   False     False       False       False
# Cold Resistance        False   False     False       False       False
#
#                        Lightning Lad  Lightning Lord  Little Epic  \
# Agility                        False           False        False
# Accelerated Healing            False           False        False
# Lantern Power Ring             False           False        False
# Dimensional Awareness          False           False        False
# Cold Resistance                False           False        False
#
#                        Living Brain  Living Tribunal  Liz Sherman  Lizard  \
# Agility                       False             True        False   False
# Accelerated Healing           False             True        False   False
# Lantern Power Ring            False            False        False   False
# Dimensional Awareness         False             True        False   False
# Cold Resistance               False            False        False   False
#
#                         Lobo   Loki  Longshot  Lord Voldemort  Luke Cage  \
# Agility                False  False      True           False      False
# Accelerated Healing    False   True     False            True       True
# Lantern Power Ring     False  False     False           False      False
# Dimensional Awareness  False  False     False           False      False
# Cold Resistance        False  False     False           False      False
#
#                        Luke Campbell  Luke Skywalker   Luna   Lyja  MODOK  \
# Agility                        False            True  False  False   True
# Accelerated Healing            False            True  False  False  False
# Lantern Power Ring             False           False  False  False  False
# Dimensional Awareness          False           False  False  False  False
# Cold Resistance                False           False  False  False  False
#
#                        Mach-IV  Machine Man  Magneto  Magog  Magus  \
# Agility                  False        False    False  False  False
# Accelerated Healing      False        False    False  False  False
# Lantern Power Ring       False        False    False  False  False
# Dimensional Awareness    False        False    False  False  False
# Cold Resistance          False        False    False  False  False
#
#                        Man of Miracles  Man-Bat  Man-Thing  Man-Wolf  \
# Agility                          False     True      False      True
# Accelerated Healing               True    False      False      True
# Lantern Power Ring               False    False      False     False
# Dimensional Awareness             True    False      False     False
# Cold Resistance                  False    False      False     False
#
#                        Mandarin  Mantis  Martian Manhunter  Marvel Girl  \
# Agility                   False   False               True        False
# Accelerated Healing       False    True              False        False
# Lantern Power Ring        False   False              False        False
# Dimensional Awareness     False   False              False        False
# Cold Resistance           False   False              False        False
#
#                        Master Brood  Master Chief  Match  Matt Parkman  \
# Agility                       False          True  False         False
# Accelerated Healing            True          True   True         False
# Lantern Power Ring            False         False  False         False
# Dimensional Awareness         False         False  False         False
# Cold Resistance               False         False  False         False
#
#                        Maverick  Maxima  Maya Herrera  Medusa  Meltdown  \
# Agility                   False   False         False   False      True
# Accelerated Healing       False   False         False   False     False
# Lantern Power Ring        False   False         False   False     False
# Dimensional Awareness     False   False         False   False     False
# Cold Resistance           False   False         False   False     False
#
#                        Mephisto   Mera  Metallo  Metamorpho  Metron  \
# Agility                   False  False    False       False   False
# Accelerated Healing        True  False    False       False   False
# Lantern Power Ring        False  False    False       False   False
# Dimensional Awareness      True  False    False       False   False
# Cold Resistance           False   True    False       False   False
#
#                        Micah Sanders  Michelangelo  Micro Lad  Mimic  \
# Agility                        False          True      False  False
# Accelerated Healing            False          True      False  False
# Lantern Power Ring             False         False      False  False
# Dimensional Awareness          False         False      False  False
# Cold Resistance                False         False      False  False
#
#                        Minna Murray  Misfit  Miss Martian  Mister Fantastic  \
# Agility                       False   False         False             False
# Accelerated Healing           False    True          True             False
# Lantern Power Ring            False   False         False             False
# Dimensional Awareness         False   False         False             False
# Cold Resistance               False   False         False             False
#
#                        Mister Freeze  Mister Knife  Mister Mxyzptlk  \
# Agility                        False         False             True
# Accelerated Healing            False         False             True
# Lantern Power Ring             False         False            False
# Dimensional Awareness          False         False             True
# Cold Resistance                 True         False            False
#
#                        Mister Sinister  Mockingbird  Mohinder Suresh  \
# Agility                          False         True            False
# Accelerated Healing               True         True            False
# Lantern Power Ring               False        False            False
# Dimensional Awareness            False        False            False
# Cold Resistance                  False        False            False
#
#                        Molten Man  Monarch  Monica Dawson  Moon Knight  \
# Agility                     False    False          False        False
# Accelerated Healing         False    False          False        False
# Lantern Power Ring          False    False          False        False
# Dimensional Awareness       False    False          False        False
# Cold Resistance             False    False          False        False
#
#                        Moonstone  Morlun  Moses Magnum  Mr Immortal  \
# Agility                    False    True         False        False
# Accelerated Healing        False   False         False         True
# Lantern Power Ring         False   False         False        False
# Dimensional Awareness      False   False         False        False
# Cold Resistance            False   False         False        False
#
#                        Mr Incredible  Ms Marvel II  Multiple Man  Mysterio  \
# Agility                        False         False         False     False
# Accelerated Healing            False         False         False     False
# Lantern Power Ring             False         False         False     False
# Dimensional Awareness          False         False         False     False
# Cold Resistance                False         False         False     False
#
#                        Mystique  Namor  Namora  Namorita  Naruto Uzumaki  \
# Agility                    True   True   False      True            True
# Accelerated Healing        True   True    True      True            True
# Lantern Power Ring        False  False   False     False           False
# Dimensional Awareness     False  False   False     False           False
# Cold Resistance           False   True   False     False           False
#
#                        Nathan Petrelli  Nebula  Negasonic Teenage Warhead  \
# Agility                          False   False                      False
# Accelerated Healing              False   False                      False
# Lantern Power Ring               False   False                      False
# Dimensional Awareness            False   False                      False
# Cold Resistance                  False   False                      False
#
#                        Nick Fury  Nightcrawler  Nightwing  Niki Sanders  \
# Agility                    False          True       True         False
# Accelerated Healing        False         False      False         False
# Lantern Power Ring         False         False      False         False
# Dimensional Awareness      False         False      False         False
# Cold Resistance            False         False      False         False
#
#                        Nina Theroux  Northstar   Nova   Odin  Offspring  \
# Agility                       False      False   True   True      False
# Accelerated Healing           False      False   True   True      False
# Lantern Power Ring            False      False  False  False      False
# Dimensional Awareness         False      False  False  False      False
# Cold Resistance               False      False  False  False       True
#
#                        Omniscient  One Punch Man  One-Above-All  Onslaught  \
# Agility                     False           True           True      False
# Accelerated Healing         False          False           True      False
# Lantern Power Ring          False          False          False      False
# Dimensional Awareness       False          False           True       True
# Cold Resistance             False          False          False      False
#
#                        Oracle  Orion  Osiris  Overtkill  Ozymandias  \
# Agility                 False   True   False      False        True
# Accelerated Healing     False   True   False      False       False
# Lantern Power Ring      False  False   False      False       False
# Dimensional Awareness   False  False   False      False       False
# Cold Resistance         False  False   False      False       False
#
#                        Parademon  Peek-a-Boo  Penance II  Penguin  \
# Agility                    False       False       False    False
# Accelerated Healing        False       False       False    False
# Lantern Power Ring         False       False       False    False
# Dimensional Awareness      False       False       False    False
# ...
# Cold Resistance        False  False          False     False      False
#
#                        Red Hood  Red Hulk  Red Mist  Red Robin  Red Skull  \
# Agility                    True     False      True       True      False
# Accelerated Healing       False      True     False      False      False
# Lantern Power Ring        False     False     False      False      False
# Dimensional Awareness     False     False     False      False      False
# Cold Resistance           False     False     False      False      False
#
#                        Red Tornado  Redeemer II  Redeemer III    Rey  Rhino  \
# Agility                       True        False         False   True  False
# Accelerated Healing          False        False         False  False  False
# Lantern Power Ring           False        False         False  False  False
# Dimensional Awareness        False        False         False  False  False
# Cold Resistance              False        False         False  False   True
#
#                        Rick Flag  Riddler  Rip Hunter  Ripcord  Robin  \
# Agility                    False    False       False    False  False
# Accelerated Healing        False    False       False    False  False
# Lantern Power Ring         False    False       False    False  False
# Dimensional Awareness      False    False        True    False  False
# Cold Resistance            False    False       False    False  False
#
#                        Robin II  Robin III  Robin V  Robin VI  Rocket Raccoon  \
# Agility                    True       True     True      True            True
# Accelerated Healing       False      False    False     False           False
# Lantern Power Ring        False      False    False     False           False
# Dimensional Awareness     False      False    False     False           False
# Cold Resistance           False      False    False     False            True
#
#                        Rogue  Rorschach   SHDB  Sabretooth   Sage  Sandman  \
# Agility                False       True  False        True  False     True
# Accelerated Healing    False      False  False        True  False    False
# Lantern Power Ring     False      False  False       False  False    False
# Dimensional Awareness  False      False  False       False  False    False
# Cold Resistance        False      False  False        True  False    False
#
#                        Sasquatch  Sauron  Savage Dragon  Scarecrow  \
# Agility                     True   False          False      False
# Accelerated Healing        False    True           True      False
# Lantern Power Ring         False   False          False      False
# Dimensional Awareness      False   False          False      False
# Cold Resistance            False   False          False      False
#
#                        Scarlet Spider  Scarlet Spider II  Scarlet Witch  \
# Agility                          True               True           True
# Accelerated Healing              True               True          False
# Lantern Power Ring              False              False          False
# Dimensional Awareness           False              False           True
# Cold Resistance                 False              False          False
#
#                        Scorpia  Scorpion  Sebastian Shaw  Sentry  Shadow King  \
# Agility                  False      True            True    True        False
# Accelerated Healing      False     False           False    True        False
# Lantern Power Ring       False     False           False   False        False
# Dimensional Awareness    False     False           False   False        False
# Cold Resistance          False     False           False   False        False
#
#                        Shadow Lass  Shadowcat  Shang-Chi  Shatterstar  \
# Agility                       True      False       True         True
# Accelerated Healing          False      False      False         True
# Lantern Power Ring           False      False      False        False
# Dimensional Awareness        False      False      False        False
# Cold Resistance              False      False      False        False
#
#                        She-Hulk  She-Thing  Shocker  Shriek    Sif   Silk  \
# Agility                   False      False    False   False   True   True
# Accelerated Healing        True      False    False   False   True   True
# Lantern Power Ring        False      False    False   False  False  False
# Dimensional Awareness     False      False    False   False  False  False
# Cold Resistance           False       True    False   False  False  False
#
#                        Silk Spectre  Silk Spectre II  Silver Surfer  \
# Agility                       False            False           True
# Accelerated Healing           False            False          False
# Lantern Power Ring            False            False          False
# Dimensional Awareness         False            False           True
# Cold Resistance               False            False          False
#
#                        Silverclaw  Simon Baz  Sinestro  Siren  Siren II  \
# Agility                      True       True      True  False     False
# Accelerated Healing         False       True     False  False     False
# Lantern Power Ring          False       True     False  False     False
# Dimensional Awareness       False      False     False  False     False
# Cold Resistance             False      False     False   True     False
#
#                        Siryn  Skaar  Snowbird  Sobek  Solomon Grundy  \
# Agility                False  False     False  False           False
# Accelerated Healing    False   True      True  False           False
# Lantern Power Ring     False  False     False  False           False
# Dimensional Awareness  False  False     False  False           False
# Cold Resistance        False  False     False  False            True
#
#                        Songbird  Space Ghost  Spawn  Spectre  Speedball  \
# Agility                    True         True   True     True      False
# Accelerated Healing       False        False  False     True      False
# Lantern Power Ring        False        False  False    False      False
# Dimensional Awareness     False        False  False     True      False
# Cold Resistance           False        False  False    False      False
#
#                        Speedy  Spider-Girl  Spider-Gwen  Spider-Man  \
# Agility                 False         True         True        True
# Accelerated Healing     False         True         True        True
# Lantern Power Ring      False        False        False       False
# Dimensional Awareness   False        False        False       False
# Cold Resistance         False        False        False       False
#
#                        Spider-Woman  Spider-Woman III  Spider-Woman IV  Spock  \
# Agility                        True              True             True  False
# Accelerated Healing           False             False            False  False
# Lantern Power Ring            False             False            False  False
# Dimensional Awareness         False             False            False  False
# Cold Resistance               False             False            False  False
#
#                        Spyke  Star-Lord  Stardust  Starfire  Stargirl  Static  \
# Agility                False       True     False     False      True    True
# Accelerated Healing     True      False     False     False     False    True
# Lantern Power Ring     False      False     False     False     False   False
# Dimensional Awareness  False      False     False     False     False   False
# Cold Resistance        False      False     False     False     False   False
#
#                        Steel  Stephanie Powell  Steppenwolf  Storm  \
# Agility                False             False         True  False
# Accelerated Healing    False              True         True  False
# Lantern Power Ring     False             False        False  False
# Dimensional Awareness  False             False        False  False
# Cold Resistance        False             False        False   True
#
#                        Stormtrooper  Stretch Armstrong  Sunspot  Superboy  \
# Agility                       False              False    False     False
# Accelerated Healing           False              False     True      True
# Lantern Power Ring            False              False    False     False
# Dimensional Awareness         False              False    False     False
# Cold Resistance               False              False    False     False
#
#                        Superboy-Prime  Supergirl  Superman  Swamp Thing  \
# Agility                         False       True      True        False
# Accelerated Healing              True       True      True        False
# Lantern Power Ring              False      False     False        False
# Dimensional Awareness           False      False     False        False
# Cold Resistance                 False       True      True        False
#
#                        Swarm  Sylar  Synch  T-1000  T-800  T-850    T-X  \
# Agility                False  False  False    True  False  False   True
# Accelerated Healing    False  False  False    True  False   True   True
# Lantern Power Ring     False  False  False   False  False  False  False
# Dimensional Awareness  False  False  False   False  False  False  False
# Cold Resistance        False  False  False    True   True   True   True
#
#                         TEST  Taskmaster  Tempest  Thanos  The Cape  \
# Agility                False        True    False    True     False
# Accelerated Healing    False       False    False    True     False
# Lantern Power Ring     False       False    False   False     False
# Dimensional Awareness  False       False    False   False     False
# Cold Resistance        False       False    False    True     False
#
#                        The Comedian  Thing   Thor  Thor Girl  Thunderbird  \
# Agility                       False  False   True      False        False
# Accelerated Healing           False  False   True      False        False
# Lantern Power Ring            False  False  False      False        False
# Dimensional Awareness         False  False  False      False        False
# Cold Resistance               False   True  False      False        False
#
#                        Thunderbird III  Thunderstrike  Thundra  Tiger Shark  \
# Agility                          False          False     True         True
# Accelerated Healing              False           True    False         True
# Lantern Power Ring               False          False    False        False
# Dimensional Awareness            False          False    False        False
# Cold Resistance                  False          False    False         True
#
#                        Tigra  Tinkerer  Titan   Toad  Tommy Clarke  Toxin  \
# Agility                 True     False  False   True         False   True
# Accelerated Healing    False     False  False   True         False   True
# Lantern Power Ring     False     False  False  False         False  False
# Dimensional Awareness  False     False  False  False         False  False
# Cold Resistance        False     False  False  False         False  False
#
#                        Tracy Strauss  Trickster  Trigon  Triplicate Girl  \
# Agility                        False      False   False            False
# Accelerated Healing            False      False    True            False
# Lantern Power Ring             False      False   False            False
# Dimensional Awareness          False      False   False            False
# Cold Resistance                 True      False   False            False
#
#                        Triton  Tyrant  Ultragirl  Ultron  Utgard-Loki  \
# Agility                  True   False      False    True        False
# Accelerated Healing     False   False      False   False        False
# Lantern Power Ring      False   False      False   False        False
# Dimensional Awareness   False   False      False   False        False
# Cold Resistance          True   False      False   False        False
#
#                        Valerie Hart  Valkyrie  Vanisher  Vegeta  Venom  \
# Agility                        True     False     False    True  False
# Accelerated Healing           False     False     False    True   True
# Lantern Power Ring            False     False     False   False  False
# Dimensional Awareness         False     False     False   False  False
# Cold Resistance               False     False     False   False  False
#
#                        Venom II  Venom III  Venompool  Vertigo II   Vibe  \
# Agility                    True       True       True       False  False
# Accelerated Healing       False       True       True       False  False
# Lantern Power Ring        False      False      False       False  False
# Dimensional Awareness     False      False       True       False   True
# Cold Resistance           False      False      False       False  False
#
#                        Vindicator  Violator  Violet Parr  Vision  Vixen  \
# Agility                     False     False        False   False   True
# Accelerated Healing         False     False        False   False   True
# Lantern Power Ring          False     False        False   False  False
# Dimensional Awareness       False     False        False   False  False
# Cold Resistance             False     False        False   False  False
#
#                        Vulture  Walrus  War Machine  Warlock   Warp  Warpath  \
# Agility                   True   False        False     True  False     True
# Accelerated Healing      False   False        False    False  False    False
# Lantern Power Ring       False   False        False    False  False    False
# Dimensional Awareness    False   False        False    False  False    False
# Cold Resistance          False   False        False    False  False     True
#
#                         Wasp  Watcher  Weapon XI  White Canary  Wildfire  \
# Agility                 True    False       True          True     False
# Accelerated Healing    False    False       True         False     False
# Lantern Power Ring     False    False      False         False     False
# Dimensional Awareness  False     True      False         False     False
# Cold Resistance        False    False      False         False     False
#
#                        Winter Soldier  Wolfsbane  Wolverine  Wonder Girl  \
# Agility                         False      False       True         True
# Accelerated Healing             False      False       True        False
# Lantern Power Ring              False      False      False        False
# Dimensional Awareness           False      False      False        False
# Cold Resistance                 False      False       True        False
#
#                        Wonder Man  Wonder Woman   X-23  X-Man  Yellowjacket  \
# Agility                     False         False   True  False         False
# Accelerated Healing         False          True   True  False         False
# Lantern Power Ring          False         False  False  False         False
# Dimensional Awareness       False         False  False  False         False
# Cold Resistance             False         False  False  False         False
#
#                        Yellowjacket II   Ymir   Yoda  Zatanna   Zoom
# Agility                          False  False   True    False  False
# Accelerated Healing              False  False  False    False  False
# Lantern Power Ring               False  False  False    False  False
# Dimensional Awareness            False  False  False    False  False
# Cold Resistance                  False   True  False    False  False

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == '3-D Man'

# The last column should be 'Zoom'
assert powers_df.columns[-1] == 'Zoom'

# The first index should be 'Agility'
assert powers_df.index[0] == 'Agility'

# The last index should be 'Omniscient'
assert powers_df.index[-1] == 'Omniscient'

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(5, random_state=1)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(5, random_state=1)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
We would rather fill in the missing values because the percentage of missing values in the dataframe is relatively low
compared to the percentage of values present. It would be easier to fill in the values using the mode string value.
"""
# Out:
# '\nWe would rather fill in the missing values because the percentage of missing values in the dataframe is relatively low\ncompared to the percentage of values present. It would be easier to fill in the values using the mode string value.\n'

# %% [markdown]
# Now, implement your chosen strategy using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
print(heroes_df['Publisher'].mode())
# Out:
# 0    Marvel Comics
# dtype: object

# %%
# Your code here
heroes_df['Publisher'].fillna('Marvel Comics', inplace=True)
heroes_df.isna().sum()
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        2
# dtype: int64

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        394
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Marvel                 9
# HarperCollins          6
# Star Trek              6
# Team Epic TV           5
# SyFy                   5
# IDW Publishing         4
# Shueisha               4
# ABC Studios            4
# Icon Comics            4
#  DC Comics             3
# Wildstorm              3
# Sony Pictures          2
# Universal Studios      1
# Hanna-Barbera          1
# J. K. Rowling          1
# Rebellion              1
# J. R. R. Tolkien       1
# South Park             1
# Microsoft              1
# Titan Books            1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
1. DC Comics and DC comics with an extra space 
2. Marvel Comics and Marvel
"""
# Out:
# '\n1. DC Comics and DC comics with an extra space \n2. Marvel Comics and Marvel\n'

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
type(heroes_df['Publisher'])
# Out:
# pandas.core.series.Series

# %%
# Your code here
heroes_df['Publisher'] = heroes_df['Publisher'].replace('Marvel', 'Marvel Comics')
heroes_df['Publisher'] = heroes_df['Publisher'].str.strip()

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        403
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Image Comics          14
# George Lucas          14
# Star Trek              6
# HarperCollins          6
# SyFy                   5
# Team Epic TV           5
# ABC Studios            4
# Icon Comics            4
# Shueisha               4
# IDW Publishing         4
# Wildstorm              3
# Sony Pictures          2
# J. K. Rowling          1
# Titan Books            1
# Hanna-Barbera          1
# J. R. R. Tolkien       1
# Universal Studios      1
# Rebellion              1
# South Park             1
# Microsoft              1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
powers_df.columns
# Out:
# Index(['3-D Man', 'A-Bomb', 'Abe Sapien', 'Abin Sur', 'Abomination', 'Abraxas',
#        'Absorbing Man', 'Adam Monroe', 'Adam Strange', 'Agent Bob',
#        ...
#        'Wonder Man', 'Wonder Woman', 'X-23', 'X-Man', 'Yellowjacket',
#        'Yellowjacket II', 'Ymir', 'Yoda', 'Zatanna', 'Zoom'],
#       dtype='object', length=667)

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [734 rows x 10 columns]

# %%
# Run this cell without changes
powers_df['3-D Man']
# Out:
# Agility                   True
# Accelerated Healing      False
# Lantern Power Ring       False
# Dimensional Awareness    False
# Cold Resistance          False
#                          ...
# Phoenix Force            False
# Molecular Dissipation    False
# Vision - Cryo            False
# Omnipresent              False
# Omniscient               False
# Name: 3-D Man, Length: 167, dtype: bool

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
The shared key is the names column in heroes_df and the column names in powers_df.
"""
# Out:
# '\nThe shared key is the names column in heroes_df and the column names in powers_df.\n'

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
powers_df_transposed = powers_df.T
powers_df_transposed.index.name = 'name'
powers_df_transposed.reset_index(inplace=True)
powers_df_transposed
# Out:
#                 name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                    False            False       False    False
# 1                    False            False        True    False
# 2                    False             True        True    False
# 3                    False            False       False    False
# 4                    False            False       False    False
# ..                     ...              ...         ...      ...
# 662                  False            False       False    False
# 663                  False             True        True    False
# 664                  False            False       False     True
# 665                  False            False       False    False
# 666                  False            False       False    False
#
#      Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0                False   False         False                 False
# 1                False   False         False                 False
# 2                False   False         False                  True
# 3                False   False         False                 False
# 4                False   False         False                 False
# ..                 ...     ...           ...                   ...
# 662              False    True         False                 False
# 663              False   False         False                 False
# 664              False   False          True                 False
# 665              False   False         False                 False
# 666              False   False         False                 False
#
#      Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 0           False           False               False              False
# 1           False           False               False              False
# 2            True            True               False              False
# 3           False           False               False              False
# 4           False           False               False              False
# ..            ...             ...                 ...                ...
# 662         False           False               False              False
# 663         False           False               False              False
# 664          True            True               False              False
# 665         False           False               False              False
# 666         False           False               False              False
#
#      Longevity  Intelligence  Super Strength  Cryokinesis  Telepathy  \
# 0        False         False            True        False      False
# 1         True         False            True        False      False
# 2         True          True            True        False       True
# 3        False         False           False        False      False
# 4        False          True            True        False      False
# ..         ...           ...             ...          ...        ...
# 662      False         False           False        False      False
# 663       True         False            True         True      False
# 664       True          True           False        False       True
# 665      False         False           False         True       True
# 666      False         False           False        False      False
#
#      Energy Armor  Energy Blasts  Duplication  Size Changing  Density Control  \
# 0           False          False        False          False            False
# 1           False          False        False          False            False
# 2           False          False        False          False            False
# 3           False          False        False          False            False
# 4           False          False        False          False            False
# ..            ...            ...          ...            ...              ...
# 662         False           True        False           True            False
# 663         False          False        False          False            False
# 664         False           True        False          False            False
# 665         False          False        False          False            False
# 666         False          False        False          False            False
#
#      Stamina  Astral Travel  Audio Control  Dexterity  Omnitrix  Super Speed  \
# 0       True          False          False      False     False         True
# 1       True          False          False      False     False        False
# 2       True          False          False      False     False        False
# 3      False          False          False      False     False        False
# 4       True          False          False      False     False         True
# ..       ...            ...            ...        ...       ...          ...
# 662    False          False          False      False     False        False
# 663    False          False          False      False     False        False
# 664     True          False          False      False     False         True
# 665    False          False          False      False     False        False
# 666    False          False          False      False     False         True
#
#      Possession  Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0         False                   False                False           False
# 1         False                   False                False           False
# 2         False                   False                False           False
# 3         False                   False                False           False
# 4         False                   False                False           False
# ..          ...                     ...                  ...             ...
# 662       False                   False                False           False
# 663       False                   False                False           False
# 664       False                   False                False           False
# 665       False                   False                False           False
# 666       False                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                     False        False          False            False
# 1                     False        False          False            False
# 2                     False        False          False            False
# 3                     False        False          False            False
# 4                     False        False          False            False
# ..                      ...          ...            ...              ...
# 662                   False        False          False            False
# 663                   False        False          False            False
# 664                   False        False          False            False
# 665                   False        False          False            False
# 666                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0          False         False  False         False  False         False
# 1          False         False  False         False  False         False
# 2          False         False  False         False  False         False
# 3          False         False  False         False  False         False
# 4          False         False  False         False  False         False
# ..           ...           ...    ...           ...    ...           ...
# 662        False         False  False         False  False         False
# 663        False         False  False         False  False         False
# 664         True         False  False         False   True         False
# 665        False         False   True         False  False         False
# 666        False         False  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0                 False        False          False                 False
# 1                 False        False          False                 False
# 2                 False        False          False                 False
# 3                 False        False          False                 False
# 4                 False        False          False                 False
# ..                  ...          ...            ...                   ...
# 662               False        False          False                 False
# 663               False        False          False                 False
# 664               False        False          False                 False
# 665               False        False          False                 False
# 666               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0          False       False            False    False              False
# 1          False        True            False    False              False
# 2           True       False            False    False              False
# 3          False       False            False    False              False
# 4          False       False            False    False              False
# ..           ...         ...              ...      ...                ...
# 662        False       False            False    False              False
# 663         True       False            False    False              False
# 664        False       False            False    False              False
# 665        False       False            False    False              False
# 666        False       False            False    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 0                   False         False       False      False
# 1                   False         False       False      False
# 2                   False         False       False      False
# 3                   False         False       False      False
# 4                   False         False       False      False
# ..                    ...           ...         ...        ...
# 662                 False         False       False      False
# 663                 False         False       False      False
# 664                 False         False       False      False
# 665                 False          True       False      False
# 666                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 0              False     False            False              False
# 1              False     False            False              False
# 2              False      True            False              False
# 3              False     False            False              False
# 4              False     False             True              False
# ..               ...       ...              ...                ...
# 662            False     False            False              False
# 663            False     False            False              False
# 664            False      True            False              False
# 665            False     False            False              False
# 666            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 0           False            False         False    False            False
# 1           False             True         False    False            False
# 2           False            False         False    False            False
# 3           False            False         False    False            False
# 4           False            False         False    False            False
# ..            ...              ...           ...      ...              ...
# 662         False            False         False    False            False
# 663         False            False         False    False            False
# 664          True            False         False     True            False
# 665         False            False         False    False            False
# 666         False            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 0                False           False       False                False
# 1                False           False       False                False
# 2                False           False       False                False
# 3                False           False       False                False
# 4                False           False       False                False
# ..                 ...             ...         ...                  ...
# 662              False           False       False                False
# 663              False           False       False                False
# 664              False           False       False                False
# 665              False           False       False                False
# 666              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
# ..                            ...                   ...
# 662                         False                 False
# 663                         False                 False
# 664                         False                 False
# 665                         False                 False
# 666                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 0                    False          False      False         False
# 1                    False          False      False         False
# 2                    False          False      False         False
# 3                    False          False      False         False
# 4                    False          False       True         False
# ..                     ...            ...        ...           ...
# 662                  False          False      False         False
# 663                  False          False      False         False
# 664                  False          False      False          True
# 665                  False          False      False         False
# 666                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 0           False            False             False             False
# 1           False            False             False             False
# 2           False            False             False             False
# 3           False            False             False             False
# 4           False            False             False             False
# ..            ...              ...               ...               ...
# 662         False            False             False             False
# 663         False            False             False             False
# 664         False            False             False             False
# 665         False            False             False             False
# 666         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 0         False     False         False           False          False
# 1         False     False         False           False          False
# 2         False     False         False           False          False
# 3         False     False         False           False          False
# 4         False     False         False           False          False
# ..          ...       ...           ...             ...            ...
# 662       False     False         False           False          False
# 663       False     False         False           False          False
# 664       False     False         False           False          False
# 665       False     False         False           False          False
# 666       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 0            False           False                   False            False
# 1            False           False                   False            False
# 2            False            True                   False            False
# 3            False           False                   False            False
# 4            False           False                   False            False
# ..             ...             ...                     ...              ...
# 662          False           False                   False            False
# 663          False           False                   False            False
# 664          False           False                   False            False
# 665          False           False                   False            False
# 666           True           False                   False            False
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 0         False    False       False       False                     False
# 1         False    False       False       False                     False
# 2         False    False       False       False                     False
# 3         False    False       False       False                     False
# 4         False    False       False       False                     False
# ..          ...      ...         ...         ...                       ...
# 662       False    False       False       False                     False
# 663       False    False       False       False                     False
# 664       False    False       False       False                     False
# 665       False    False       False       False                      True
# 666       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 0              False         False          False         False       False
# 1              False         False          False         False       False
# 2              False         False          False         False       False
# 3              False         False          False         False       False
# 4              False         False          False         False       False
# ..               ...           ...            ...           ...         ...
# 662            False         False          False         False       False
# 663            False         False          False         False       False
# 664            False         False          False         False       False
# 665            False         False          False         False       False
# 666            False         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 0                        False   False                False            False
# 1                        False   False                False            False
# 2                        False   False                False            False
# 3                        False   False                False            False
# 4                        False   False                False            False
# ..                         ...     ...                  ...              ...
# 662                      False   False                False            False
# 663                      False   False                False            False
# 664                      False   False                False            False
# 665                      False   False                False            False
# 666                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 0              False        False           False      False           False
# 1              False        False           False      False           False
# 2              False        False           False      False           False
# 3              False        False           False      False           False
# 4              False        False           False      False           False
# ..               ...          ...             ...        ...             ...
# 662            False        False           False      False           False
# 663            False        False           False      False           False
# 664            False        False           False      False           False
# 665            False        False           False      False           False
# 666            False         True           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 0                False         False       False     False           False
# 1                False         False       False     False           False
# 2                False         False       False     False           False
# 3                False         False       False     False           False
# 4                False         False       False     False           False
# ..                 ...           ...         ...       ...             ...
# 662              False         False       False     False           False
# 663              False         False       False     False           False
# 664              False         False       False      True           False
# 665              False         False       False     False           False
# 666              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4           False       False          False               False
# ..            ...         ...            ...                 ...
# 662         False       False          False               False
# 663         False       False          False               False
# 664         False       False          False               False
# 665         False       False           True               False
# 666         False       False          False               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 0                  False                         False              False
# 1                  False                         False              False
# 2                  False                         False              False
# 3                  False                         False              False
# 4                  False                         False              False
# ..                   ...                           ...                ...
# 662                False                         False              False
# 663                False                         False              False
# 664                False                         False              False
# 665                False                         False              False
# 666                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
# ..                 ...                   ...                   ...
# 662              False                 False                 False
# 663              False                 False                 False
# 664              False                 False                 False
# 665              False                 False                 False
# 666              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 0             False            False      False                    False
# 1             False            False      False                    False
# 2             False            False      False                    False
# 3             False            False      False                    False
# 4             False            False      False                    False
# ..              ...              ...        ...                      ...
# 662           False            False      False                    False
# 663           False            False      False                    False
# 664           False            False      False                    False
# 665           False            False      False                    False
# 666           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 0            False  False         False              False           False
# 1            False  False         False              False           False
# 2            False  False         False              False           False
# 3            False  False         False              False           False
# 4            False  False         False              False           False
# ..             ...    ...           ...                ...             ...
# 662          False  False         False              False           False
# 663          False  False         False              False           False
# 664          False  False         False              False           False
# 665          False  False         False              False           False
# 666          False  False         False               True           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 0               False         False        False                 False
# 1               False         False        False                 False
# 2               False         False         True                 False
# 3               False         False        False                 False
# 4               False         False        False                 False
# ..                ...           ...          ...                   ...
# 662             False         False        False                 False
# 663             False         False        False                 False
# 664             False         False        False                 False
# 665             False         False        False                 False
# 666             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 0                 False                 False    False         False
# 1                 False                 False    False         False
# 2                 False                 False    False         False
# 3                 False                 False    False         False
# 4                 False                 False    False         False
# ..                  ...                   ...      ...           ...
# 662               False                 False    False         False
# 663               False                 False    False         False
# 664               False                 False    False         False
# 665               False                 False    False         False
# 666               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 0           False         False           False              False
# 1           False         False           False              False
# 2           False         False           False              False
# 3           False         False           False              False
# 4            True         False           False              False
# ..            ...           ...             ...                ...
# 662         False         False           False              False
# 663         False         False           False              False
# 664         False         False           False              False
# 665         False         False           False              False
# 666         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 0           False              False      False         False         False
# 1           False              False      False         False         False
# 2           False              False      False         False         False
# 3           False              False      False         False         False
# 4           False              False      False         False         False
# ..            ...                ...        ...           ...           ...
# 662         False              False      False         False         False
# 663         False              False      False         False         False
# 664         False              False       True         False         False
# 665         False              False      False         False          True
# 666         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 0            False        False        False                False
# 1            False        False        False                False
# 2            False        False        False                False
# 3            False        False        False                False
# 4            False        False        False                False
# ..             ...          ...          ...                  ...
# 662          False        False        False                False
# 663          False        False        False                False
# 664          False        False        False                False
# 665          False        False        False                False
# 666          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 0              False           False             False         False
# 1              False           False             False         False
# 2              False           False             False         False
# 3              False           False             False         False
# 4              False           False             False         False
# ..               ...             ...               ...           ...
# 662            False           False             False         False
# 663            False           False             False         False
# 664            False           False             False         False
# 665             True           False             False         False
# 666            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 662            False       False             False        False
# 663            False       False             False        False
# 664            False       False             False        False
# 665            False       False             False        False
# 666            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 662          False                  False          False        False
# 663          False                  False          False        False
# 664          False                  False          False        False
# 665          False                  False          False        False
# 666          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 662       False
# 663       False
# 664       False
# 665       False
# 666       False
#
# [667 rows x 168 columns]

# %%
# Your code here (create more cells as needed)
heroes_and_powers_df = heroes_df.merge(powers_df_transposed, on='name',how='inner')
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 655  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 656             Ymir    Male     white        Frost Giant           No Hair
# 657             Yoda    Male     brown     Yoda's species             White
# 658          Zatanna  Female      blue              Human             Black
# 659             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  Agility  \
# 0     203.0      Marvel Comics          -      good   441.0    False
# 1     191.0  Dark Horse Comics       blue      good    65.0     True
# 2     185.0          DC Comics        red      good    90.0    False
# 3     203.0      Marvel Comics          -       bad   441.0    False
# 4     -99.0      Marvel Comics          -       bad   -99.0    False
# ..      ...                ...        ...       ...     ...      ...
# 655   165.0      Marvel Comics          -      good    52.0    False
# 656   304.8      Marvel Comics      white      good   -99.0    False
# 657    66.0       George Lucas      green      good    17.0     True
# 658   170.0          DC Comics          -      good    57.0    False
# 659   185.0          DC Comics          -       bad    81.0    False
#
#      Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                   True               False                  False
# 1                   True               False                  False
# 2                  False                True                  False
# 3                   True               False                  False
# 4                  False               False                   True
# ..                   ...                 ...                    ...
# 655                False               False                  False
# 656                False               False                  False
# 657                False               False                  False
# 658                False               False                  False
# 659                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 1               True        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 4              False       False    False              False    True
# ..               ...         ...      ...                ...     ...
# 655            False       False    False              False    True
# 656             True        True    False              False   False
# 657            False       False     True              False   False
# 658            False       False    False              False   False
# 659            False       False    False              False   False
#
#      Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# 0           False                 False         False           False
# 1           False                  True          True            True
# 2           False                 False         False           False
# 3           False                 False         False           False
# 4           False                 False         False           False
# ..            ...                   ...           ...             ...
# 655         False                 False         False           False
# 656         False                 False         False           False
# 657          True                 False          True            True
# 658         False                 False         False           False
# 659         False                 False         False           False
#
#      Power Augmentation  Animal Attributes  Longevity  Intelligence  \
# 0                 False              False       True         False
# 1                 False              False       True          True
# 2                 False              False      False         False
# 3                 False              False      False          True
# 4                 False              False      False          True
# ..                  ...                ...        ...           ...
# 655               False              False      False         False
# 656               False              False       True         False
# 657               False              False       True          True
# 658               False              False      False         False
# 659               False              False      False         False
#
#      Super Strength  Cryokinesis  Telepathy  Energy Armor  Energy Blasts  \
# 0              True        False      False         False          False
# 1              True        False       True         False          False
# 2             False        False      False         False          False
# 3              True        False      False         False          False
# 4              True        False      False         False          False
# ..              ...          ...        ...           ...            ...
# 655           False        False      False         False           True
# 656            True         True      False         False          False
# 657           False        False       True         False           True
# 658           False         True       True         False          False
# 659           False        False      False         False          False
#
#      Duplication  Size Changing  Density Control  Stamina  Astral Travel  \
# 0          False          False            False     True          False
# 1          False          False            False     True          False
# 2          False          False            False    False          False
# 3          False          False            False     True          False
# 4          False           True            False    False          False
# ..           ...            ...              ...      ...            ...
# 655        False           True            False    False          False
# 656        False          False            False    False          False
# 657        False          False            False     True          False
# 658        False          False            False    False          False
# 659        False          False            False    False          False
#
#      Audio Control  Dexterity  Omnitrix  Super Speed  Possession  \
# 0            False      False     False        False       False
# 1            False      False     False        False       False
# 2            False      False     False        False       False
# 3            False      False     False         True       False
# 4            False      False     False         True       False
# ..             ...        ...       ...          ...         ...
# 655          False      False     False        False       False
# 656          False      False     False        False       False
# 657          False      False     False         True       False
# 658          False      False     False        False       False
# 659          False      False     False         True       False
#
#      Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0                     False                False           False
# 1                     False                False           False
# 2                     False                False           False
# 3                     False                False           False
# 4                     False                False           False
# ..                      ...                  ...             ...
# 655                   False                False           False
# 656                   False                False           False
# 657                   False                False           False
# 658                   False                False           False
# 659                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                     False        False          False            False
# 1                     False        False          False            False
# 2                     False        False          False            False
# 3                     False        False          False            False
# 4                     False        False           True            False
# ..                      ...          ...            ...              ...
# 655                   False        False          False            False
# 656                   False        False          False            False
# 657                   False        False          False            False
# 658                   False        False          False            False
# 659                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0          False         False  False         False  False         False
# 1          False         False  False         False  False         False
# 2          False         False  False         False  False         False
# 3          False         False  False         False  False         False
# 4          False         False   True         False  False         False
# ..           ...           ...    ...           ...    ...           ...
# 655        False         False  False         False  False         False
# 656        False         False  False         False  False         False
# 657         True         False  False         False   True         False
# 658        False         False   True         False  False         False
# 659        False         False  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0                 False        False          False                 False
# 1                 False        False          False                 False
# 2                 False        False          False                 False
# 3                 False        False          False                 False
# 4                  True        False          False                 False
# ..                  ...          ...            ...                   ...
# 655               False        False          False                 False
# 656               False        False          False                 False
# 657               False        False          False                 False
# 658               False        False          False                 False
# 659               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0          False        True            False    False              False
# 1           True       False            False    False              False
# 2          False       False            False    False              False
# 3          False       False            False    False              False
# 4           True       False            False    False              False
# ..           ...         ...              ...      ...                ...
# 655        False       False            False    False              False
# 656         True       False            False    False              False
# 657        False       False            False    False              False
# 658        False       False            False    False              False
# 659        False       False            False    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 0                   False         False       False      False
# 1                   False         False       False      False
# 2                   False         False       False      False
# 3                   False         False       False      False
# 4                   False         False       False      False
# ..                    ...           ...         ...        ...
# 655                 False         False       False      False
# 656                 False         False       False      False
# 657                 False         False       False      False
# 658                 False          True       False      False
# 659                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 0              False     False            False              False
# 1              False      True            False              False
# 2              False     False            False              False
# 3              False     False             True              False
# 4              False     False             True              False
# ..               ...       ...              ...                ...
# 655            False     False            False              False
# 656            False     False            False              False
# 657            False      True            False              False
# 658            False     False            False              False
# 659            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 0           False             True         False    False            False
# 1           False            False         False    False            False
# 2           False            False         False    False            False
# 3           False            False         False    False            False
# 4           False            False         False    False            False
# ..            ...              ...           ...      ...              ...
# 655         False            False         False    False            False
# 656         False            False         False    False            False
# 657          True            False         False     True            False
# 658         False            False         False    False            False
# 659         False            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 0                False           False       False                False
# 1                False           False       False                False
# 2                False           False       False                False
# 3                False           False       False                False
# 4                False           False       False                False
# ..                 ...             ...         ...                  ...
# 655              False           False       False                False
# 656              False           False       False                False
# 657              False           False       False                False
# 658              False           False       False                False
# 659              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
# ..                            ...                   ...
# 655                         False                 False
# 656                         False                 False
# 657                         False                 False
# 658                         False                 False
# 659                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 0                    False          False      False         False
# 1                    False          False      False         False
# 2                    False          False      False         False
# 3                    False          False       True         False
# 4                    False          False      False         False
# ..                     ...            ...        ...           ...
# 655                  False          False      False         False
# 656                  False          False      False         False
# 657                  False          False      False          True
# 658                  False          False      False         False
# 659                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 0           False            False             False             False
# 1           False            False             False             False
# 2           False            False             False             False
# 3           False            False             False             False
# 4           False            False             False             False
# ..            ...              ...               ...               ...
# 655         False            False             False             False
# 656         False            False             False             False
# 657         False            False             False             False
# 658         False            False             False             False
# 659         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 0         False     False         False           False          False
# 1         False     False         False           False          False
# 2         False     False         False           False          False
# 3         False     False         False           False          False
# 4         False     False         False           False          False
# ..          ...       ...           ...             ...            ...
# 655       False     False         False           False          False
# 656       False     False         False           False          False
# 657       False     False         False           False          False
# 658       False     False         False           False          False
# 659       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 0            False           False                   False            False
# 1            False            True                   False            False
# 2            False           False                   False            False
# 3            False           False                   False            False
# 4            False           False                    True            False
# ..             ...             ...                     ...              ...
# 655          False           False                   False            False
# 656          False           False                   False            False
# 657          False           False                   False            False
# 658          False           False                   False            False
# 659           True           False                   False            False
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 0         False    False       False       False                     False
# 1         False    False       False       False                     False
# 2         False    False       False       False                     False
# 3         False    False       False       False                     False
# 4         False    False       False       False                     False
# ..          ...      ...         ...         ...                       ...
# 655       False    False       False       False                     False
# 656       False    False       False       False                     False
# 657       False    False       False       False                     False
# 658       False    False       False       False                      True
# 659       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 0              False         False          False         False       False
# 1              False         False          False         False       False
# 2              False         False          False         False       False
# 3              False         False          False         False       False
# 4              False         False          False         False       False
# ..               ...           ...            ...           ...         ...
# 655            False         False          False         False       False
# 656            False         False          False         False       False
# 657            False         False          False         False       False
# 658            False         False          False         False       False
# 659            False         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 0                        False   False                False            False
# 1                        False   False                False            False
# 2                        False   False                False            False
# 3                        False   False                False            False
# 4                        False   False                 True            False
# ..                         ...     ...                  ...              ...
# 655                      False   False                False            False
# 656                      False   False                False            False
# 657                      False   False                False            False
# 658                      False   False                False            False
# 659                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 0              False        False           False      False           False
# 1              False        False           False      False           False
# 2              False        False           False      False           False
# 3              False        False           False      False           False
# 4              False        False           False      False           False
# ..               ...          ...             ...        ...             ...
# 655            False        False           False      False           False
# 656            False        False           False      False           False
# 657            False        False           False      False           False
# 658            False        False           False      False           False
# 659            False         True           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 0                False         False       False     False           False
# 1                False         False       False     False           False
# 2                False         False       False     False           False
# 3                False         False       False     False           False
# 4                False         False       False     False           False
# ..                 ...           ...         ...       ...             ...
# 655              False         False       False     False           False
# 656              False         False       False     False           False
# 657              False         False       False      True           False
# 658              False         False       False     False           False
# 659              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4            True       False          False               False
# ..            ...         ...            ...                 ...
# 655         False       False          False               False
# 656         False       False          False               False
# 657         False       False          False               False
# 658         False       False           True               False
# 659         False       False          False               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 0                  False                         False              False
# 1                  False                         False              False
# 2                  False                         False              False
# 3                  False                         False              False
# 4                  False                         False              False
# ..                   ...                           ...                ...
# 655                False                         False              False
# 656                False                         False              False
# 657                False                         False              False
# 658                False                         False              False
# 659                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
# ..                 ...                   ...                   ...
# 655              False                 False                 False
# 656              False                 False                 False
# 657              False                 False                 False
# 658              False                 False                 False
# 659              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 0             False            False      False                    False
# 1             False            False      False                    False
# 2             False            False      False                    False
# 3             False            False      False                    False
# 4             False            False      False                    False
# ..              ...              ...        ...                      ...
# 655           False            False      False                    False
# 656           False            False      False                    False
# 657           False            False      False                    False
# 658           False            False      False                    False
# 659           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 0            False  False         False              False           False
# 1            False  False         False              False           False
# 2            False  False         False              False           False
# 3            False  False         False              False           False
# 4            False  False         False              False           False
# ..             ...    ...           ...                ...             ...
# 655          False  False         False              False           False
# 656          False  False         False              False           False
# 657          False  False         False              False           False
# 658          False  False         False              False           False
# 659          False  False         False               True           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 0               False         False        False                 False
# 1               False         False         True                 False
# 2               False         False        False                 False
# 3               False         False        False                 False
# 4               False         False        False                 False
# ..                ...           ...          ...                   ...
# 655             False         False        False                 False
# 656             False         False        False                 False
# 657             False         False        False                 False
# 658             False         False        False                 False
# 659             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 0                 False                 False    False         False
# 1                 False                 False    False         False
# 2                 False                 False    False         False
# 3                 False                 False    False         False
# 4                 False                 False    False         False
# ..                  ...                   ...      ...           ...
# 655               False                 False    False         False
# 656               False                 False    False         False
# 657               False                 False    False         False
# 658               False                 False    False         False
# 659               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 0           False         False           False              False
# 1           False         False           False              False
# 2           False         False           False              False
# 3            True         False           False              False
# 4           False         False           False              False
# ..            ...           ...             ...                ...
# 655         False         False           False              False
# 656         False         False           False              False
# 657         False         False           False              False
# 658         False         False           False              False
# 659         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 0           False              False      False         False         False
# 1           False              False      False         False         False
# 2           False              False      False         False         False
# 3           False              False      False         False         False
# 4           False              False      False         False         False
# ..            ...                ...        ...           ...           ...
# 655         False              False      False         False         False
# 656         False              False      False         False         False
# 657         False              False       True         False         False
# 658         False              False      False         False          True
# 659         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 0            False        False        False                False
# 1            False        False        False                False
# 2            False        False        False                False
# 3            False        False        False                False
# 4            False        False        False                False
# ..             ...          ...          ...                  ...
# 655          False        False        False                False
# 656          False        False        False                False
# 657          False        False        False                False
# 658          False        False        False                False
# 659          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 0              False           False             False         False
# 1              False           False             False         False
# 2              False           False             False         False
# 3              False           False             False         False
# 4              False           False             False         False
# ..               ...             ...               ...           ...
# 655            False           False             False         False
# 656            False           False             False         False
# 657            False           False             False         False
# 658             True           False             False         False
# 659            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 655            False       False             False        False
# 656            False       False             False        False
# 657            False       False             False        False
# 658            False       False             False        False
# 659            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 655          False                  False          False        False
# 656          False                  False          False        False
# 657          False                  False          False        False
# 658          False                  False          False        False
# 659          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 655       False
# 656       False
# 657       False
# 658       False
# 659       False
#
# [660 rows x 177 columns]

# %%
#heroes_and_powers_df.loc[heroes_and_power_df['Publisher'] == 'Marvel Comics']
heroes_and_powers_df[(heroes_and_powers_df['Publisher'] == "Marvel Comics") & (heroes_and_powers_df['Agility'] == True)].count()
# Out:
# name                     134
# Gender                   134
# Eye color                134
# Race                     134
# Hair color               134
#                         ...
# Phoenix Force            134
# Molecular Dissipation    134
# Vision - Cryo            134
# Omnipresent              134
# Omniscient               134
# Length: 177, dtype: int64

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a DataFrame with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you might need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-297-f29b83d3d730> in <module>
#       5
#       6 # Confirms you have the right number of rows
# ----> 7 assert heroes_and_powers_df.shape[0] == 647
#       8
#       9 # Confirms you have the necessary columns
#
# AssertionError:

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum([heroes_and_powers_df[power_name] for power_name in powers_df.index])
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 655  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 656             Ymir    Male     white        Frost Giant           No Hair
# 657             Yoda    Male     brown     Yoda's species             White
# 658          Zatanna  Female      blue              Human             Black
# 659             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  Agility  \
# 0     203.0      Marvel Comics          -      good   441.0    False
# 1     191.0  Dark Horse Comics       blue      good    65.0     True
# 2     185.0          DC Comics        red      good    90.0    False
# 3     203.0      Marvel Comics          -       bad   441.0    False
# 4     -99.0      Marvel Comics          -       bad   -99.0    False
# ..      ...                ...        ...       ...     ...      ...
# 655   165.0      Marvel Comics          -      good    52.0    False
# 656   304.8      Marvel Comics      white      good   -99.0    False
# 657    66.0       George Lucas      green      good    17.0     True
# 658   170.0          DC Comics          -      good    57.0    False
# 659   185.0          DC Comics          -       bad    81.0    False
#
#      Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                   True               False                  False
# 1                   True               False                  False
# 2                  False                True                  False
# 3                   True               False                  False
# 4                  False               False                   True
# ..                   ...                 ...                    ...
# 655                False               False                  False
# 656                False               False                  False
# 657                False               False                  False
# 658                False               False                  False
# 659                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 1               True        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 4              False       False    False              False    True
# ..               ...         ...      ...                ...     ...
# 655            False       False    False              False    True
# 656             True        True    False              False   False
# 657            False       False     True              False   False
# 658            False       False    False              False   False
# 659            False       False    False              False   False
#
#      Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# 0           False                 False         False           False
# 1           False                  True          True            True
# 2           False                 False         False           False
# 3           False                 False         False           False
# 4           False                 False         False           False
# ..            ...                   ...           ...             ...
# 655         False                 False         False           False
# 656         False                 False         False           False
# 657          True                 False          True            True
# 658         False                 False         False           False
# 659         False                 False         False           False
#
#      Power Augmentation  Animal Attributes  Longevity  Intelligence  \
# 0                 False              False       True         False
# 1                 False              False       True          True
# 2                 False              False      False         False
# 3                 False              False      False          True
# 4                 False              False      False          True
# ..                  ...                ...        ...           ...
# 655               False              False      False         False
# 656               False              False       True         False
# 657               False              False       True          True
# 658               False              False      False         False
# 659               False              False      False         False
#
#      Super Strength  Cryokinesis  Telepathy  Energy Armor  Energy Blasts  \
# 0              True        False      False         False          False
# 1              True        False       True         False          False
# 2             False        False      False         False          False
# 3              True        False      False         False          False
# 4              True        False      False         False          False
# ..              ...          ...        ...           ...            ...
# 655           False        False      False         False           True
# 656            True         True      False         False          False
# 657           False        False       True         False           True
# 658           False         True       True         False          False
# 659           False        False      False         False          False
#
#      Duplication  Size Changing  Density Control  Stamina  Astral Travel  \
# 0          False          False            False     True          False
# 1          False          False            False     True          False
# 2          False          False            False    False          False
# 3          False          False            False     True          False
# 4          False           True            False    False          False
# ..           ...            ...              ...      ...            ...
# 655        False           True            False    False          False
# 656        False          False            False    False          False
# 657        False          False            False     True          False
# 658        False          False            False    False          False
# 659        False          False            False    False          False
#
#      Audio Control  Dexterity  Omnitrix  Super Speed  Possession  \
# 0            False      False     False        False       False
# 1            False      False     False        False       False
# 2            False      False     False        False       False
# 3            False      False     False         True       False
# 4            False      False     False         True       False
# ..             ...        ...       ...          ...         ...
# 655          False      False     False        False       False
# 656          False      False     False        False       False
# 657          False      False     False         True       False
# 658          False      False     False        False       False
# 659          False      False     False         True       False
#
#      Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0                     False                False           False
# 1                     False                False           False
# 2                     False                False           False
# 3                     False                False           False
# 4                     False                False           False
# ..                      ...                  ...             ...
# 655                   False                False           False
# 656                   False                False           False
# 657                   False                False           False
# 658                   False                False           False
# 659                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                     False        False          False            False
# 1                     False        False          False            False
# 2                     False        False          False            False
# 3                     False        False          False            False
# 4                     False        False           True            False
# ..                      ...          ...            ...              ...
# 655                   False        False          False            False
# 656                   False        False          False            False
# 657                   False        False          False            False
# 658                   False        False          False            False
# 659                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0          False         False  False         False  False         False
# 1          False         False  False         False  False         False
# 2          False         False  False         False  False         False
# 3          False         False  False         False  False         False
# 4          False         False   True         False  False         False
# ..           ...           ...    ...           ...    ...           ...
# 655        False         False  False         False  False         False
# 656        False         False  False         False  False         False
# 657         True         False  False         False   True         False
# 658        False         False   True         False  False         False
# 659        False         False  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0                 False        False          False                 False
# 1                 False        False          False                 False
# 2                 False        False          False                 False
# 3                 False        False          False                 False
# 4                  True        False          False                 False
# ..                  ...          ...            ...                   ...
# 655               False        False          False                 False
# 656               False        False          False                 False
# 657               False        False          False                 False
# 658               False        False          False                 False
# 659               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0          False        True            False    False              False
# 1           True       False            False    False              False
# 2          False       False            False    False              False
# 3          False       False            False    False              False
# 4           True       False            False    False              False
# ..           ...         ...              ...      ...                ...
# 655        False       False            False    False              False
# 656         True       False            False    False              False
# 657        False       False            False    False              False
# 658        False       False            False    False              False
# 659        False       False            False    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 0                   False         False       False      False
# 1                   False         False       False      False
# 2                   False         False       False      False
# 3                   False         False       False      False
# 4                   False         False       False      False
# ..                    ...           ...         ...        ...
# 655                 False         False       False      False
# 656                 False         False       False      False
# 657                 False         False       False      False
# 658                 False          True       False      False
# 659                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 0              False     False            False              False
# 1              False      True            False              False
# 2              False     False            False              False
# 3              False     False             True              False
# 4              False     False             True              False
# ..               ...       ...              ...                ...
# 655            False     False            False              False
# 656            False     False            False              False
# 657            False      True            False              False
# 658            False     False            False              False
# 659            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 0           False             True         False    False            False
# 1           False            False         False    False            False
# 2           False            False         False    False            False
# 3           False            False         False    False            False
# 4           False            False         False    False            False
# ..            ...              ...           ...      ...              ...
# 655         False            False         False    False            False
# 656         False            False         False    False            False
# 657          True            False         False     True            False
# 658         False            False         False    False            False
# 659         False            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 0                False           False       False                False
# 1                False           False       False                False
# 2                False           False       False                False
# 3                False           False       False                False
# 4                False           False       False                False
# ..                 ...             ...         ...                  ...
# 655              False           False       False                False
# 656              False           False       False                False
# 657              False           False       False                False
# 658              False           False       False                False
# 659              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
# ..                            ...                   ...
# 655                         False                 False
# 656                         False                 False
# 657                         False                 False
# 658                         False                 False
# 659                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 0                    False          False      False         False
# 1                    False          False      False         False
# 2                    False          False      False         False
# 3                    False          False       True         False
# 4                    False          False      False         False
# ..                     ...            ...        ...           ...
# 655                  False          False      False         False
# 656                  False          False      False         False
# 657                  False          False      False          True
# 658                  False          False      False         False
# 659                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 0           False            False             False             False
# 1           False            False             False             False
# 2           False            False             False             False
# 3           False            False             False             False
# 4           False            False             False             False
# ..            ...              ...               ...               ...
# 655         False            False             False             False
# 656         False            False             False             False
# 657         False            False             False             False
# 658         False            False             False             False
# 659         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 0         False     False         False           False          False
# 1         False     False         False           False          False
# 2         False     False         False           False          False
# 3         False     False         False           False          False
# 4         False     False         False           False          False
# ..          ...       ...           ...             ...            ...
# 655       False     False         False           False          False
# 656       False     False         False           False          False
# 657       False     False         False           False          False
# 658       False     False         False           False          False
# 659       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 0            False           False                   False            False
# 1            False            True                   False            False
# 2            False           False                   False            False
# 3            False           False                   False            False
# 4            False           False                    True            False
# ..             ...             ...                     ...              ...
# 655          False           False                   False            False
# 656          False           False                   False            False
# 657          False           False                   False            False
# 658          False           False                   False            False
# 659           True           False                   False            False
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 0         False    False       False       False                     False
# 1         False    False       False       False                     False
# 2         False    False       False       False                     False
# 3         False    False       False       False                     False
# 4         False    False       False       False                     False
# ..          ...      ...         ...         ...                       ...
# 655       False    False       False       False                     False
# 656       False    False       False       False                     False
# 657       False    False       False       False                     False
# 658       False    False       False       False                      True
# 659       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 0              False         False          False         False       False
# 1              False         False          False         False       False
# 2              False         False          False         False       False
# 3              False         False          False         False       False
# 4              False         False          False         False       False
# ..               ...           ...            ...           ...         ...
# 655            False         False          False         False       False
# 656            False         False          False         False       False
# 657            False         False          False         False       False
# 658            False         False          False         False       False
# 659            False         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 0                        False   False                False            False
# 1                        False   False                False            False
# 2                        False   False                False            False
# 3                        False   False                False            False
# 4                        False   False                 True            False
# ..                         ...     ...                  ...              ...
# 655                      False   False                False            False
# 656                      False   False                False            False
# 657                      False   False                False            False
# 658                      False   False                False            False
# 659                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 0              False        False           False      False           False
# 1              False        False           False      False           False
# 2              False        False           False      False           False
# 3              False        False           False      False           False
# 4              False        False           False      False           False
# ..               ...          ...             ...        ...             ...
# 655            False        False           False      False           False
# 656            False        False           False      False           False
# 657            False        False           False      False           False
# 658            False        False           False      False           False
# 659            False         True           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 0                False         False       False     False           False
# 1                False         False       False     False           False
# 2                False         False       False     False           False
# 3                False         False       False     False           False
# 4                False         False       False     False           False
# ..                 ...           ...         ...       ...             ...
# 655              False         False       False     False           False
# 656              False         False       False     False           False
# 657              False         False       False      True           False
# 658              False         False       False     False           False
# 659              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4            True       False          False               False
# ..            ...         ...            ...                 ...
# 655         False       False          False               False
# 656         False       False          False               False
# 657         False       False          False               False
# 658         False       False           True               False
# 659         False       False          False               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 0                  False                         False              False
# 1                  False                         False              False
# 2                  False                         False              False
# 3                  False                         False              False
# 4                  False                         False              False
# ..                   ...                           ...                ...
# 655                False                         False              False
# 656                False                         False              False
# 657                False                         False              False
# 658                False                         False              False
# 659                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
# ..                 ...                   ...                   ...
# 655              False                 False                 False
# 656              False                 False                 False
# 657              False                 False                 False
# 658              False                 False                 False
# 659              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 0             False            False      False                    False
# 1             False            False      False                    False
# 2             False            False      False                    False
# 3             False            False      False                    False
# 4             False            False      False                    False
# ..              ...              ...        ...                      ...
# 655           False            False      False                    False
# 656           False            False      False                    False
# 657           False            False      False                    False
# 658           False            False      False                    False
# 659           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 0            False  False         False              False           False
# 1            False  False         False              False           False
# 2            False  False         False              False           False
# 3            False  False         False              False           False
# 4            False  False         False              False           False
# ..             ...    ...           ...                ...             ...
# 655          False  False         False              False           False
# 656          False  False         False              False           False
# 657          False  False         False              False           False
# 658          False  False         False              False           False
# 659          False  False         False               True           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 0               False         False        False                 False
# 1               False         False         True                 False
# 2               False         False        False                 False
# 3               False         False        False                 False
# 4               False         False        False                 False
# ..                ...           ...          ...                   ...
# 655             False         False        False                 False
# 656             False         False        False                 False
# 657             False         False        False                 False
# 658             False         False        False                 False
# 659             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 0                 False                 False    False         False
# 1                 False                 False    False         False
# 2                 False                 False    False         False
# 3                 False                 False    False         False
# 4                 False                 False    False         False
# ..                  ...                   ...      ...           ...
# 655               False                 False    False         False
# 656               False                 False    False         False
# 657               False                 False    False         False
# 658               False                 False    False         False
# 659               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 0           False         False           False              False
# 1           False         False           False              False
# 2           False         False           False              False
# 3            True         False           False              False
# 4           False         False           False              False
# ..            ...           ...             ...                ...
# 655         False         False           False              False
# 656         False         False           False              False
# 657         False         False           False              False
# 658         False         False           False              False
# 659         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 0           False              False      False         False         False
# 1           False              False      False         False         False
# 2           False              False      False         False         False
# 3           False              False      False         False         False
# 4           False              False      False         False         False
# ..            ...                ...        ...           ...           ...
# 655         False              False      False         False         False
# 656         False              False      False         False         False
# 657         False              False       True         False         False
# 658         False              False      False         False          True
# 659         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 0            False        False        False                False
# 1            False        False        False                False
# 2            False        False        False                False
# 3            False        False        False                False
# 4            False        False        False                False
# ..             ...          ...          ...                  ...
# 655          False        False        False                False
# 656          False        False        False                False
# 657          False        False        False                False
# 658          False        False        False                False
# 659          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 0              False           False             False         False
# 1              False           False             False         False
# 2              False           False             False         False
# 3              False           False             False         False
# 4              False           False             False         False
# ..               ...             ...               ...           ...
# 655            False           False             False         False
# 656            False           False             False         False
# 657            False           False             False         False
# 658             True           False             False         False
# 659            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 655            False       False             False        False
# 656            False       False             False        False
# 657            False       False             False        False
# 658            False       False             False        False
# 659            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 655          False                  False          False        False
# 656          False                  False          False        False
# 657          False                  False          False        False
# 658          False                  False          False        False
# 659          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 655       False            3
# 656       False            6
# 657       False           19
# 658       False            8
# 659       False            4
#
# [660 rows x 178 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"],
    y=heroes_and_powers_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#            name  Gender Eye color    Race Hair color  Height      Publisher  \
# 163  Cogliostro    Male         -       -          -   -99.0   Image Comics
# 347  King Shark    Male     black  Animal    No Hair   -99.0      DC Comics
# 75    Big Daddy    Male         -       -          -   -99.0    Icon Comics
# 118  Bomb Queen  Female         -       -          -   -99.0   Image Comics
# 630  Vindicator    Male         -       -          -   -99.0  Marvel Comics
#
#     Skin color Alignment  Weight  Agility  Accelerated Healing  \
# 163          -       bad   -99.0    False                False
# 347          -       bad   -99.0    False                False
# 75           -      good   -99.0    False                False
# 118          -       bad   -99.0    False                 True
# 630          -      good   -99.0    False                False
#
#      Lantern Power Ring  Dimensional Awareness  Cold Resistance  Durability  \
# 163               False                  False            False       False
# 347               False                  False             True        True
# 75                False                  False            False       False
# 118               False                  False            False       False
# 630               False                  False            False        True
#
#      Stealth  Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 163    False              False   False         False                 False
# 347     True              False   False         False                  True
# 75     False              False   False         False                 False
# 118    False              False   False         False                 False
# 630    False              False    True         False                 False
#
#      Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 163         False           False               False              False
# 347         False           False               False               True
# 75          False           False               False              False
# 118         False           False               False              False
# 630         False           False               False              False
#
#      Longevity  Intelligence  Super Strength  Cryokinesis  Telepathy  \
# 163      False         False           False        False      False
# 347       True         False            True        False      False
# 75       False         False           False        False      False
# 118      False         False           False        False      False
# 630      False         False           False        False      False
#
#      Energy Armor  Energy Blasts  Duplication  Size Changing  Density Control  \
# 163         False          False        False          False            False
# 347         False          False        False          False            False
# 75          False          False        False          False            False
# 118         False           True        False          False            False
# 630         False          False        False          False            False
#
#      Stamina  Astral Travel  Audio Control  Dexterity  Omnitrix  Super Speed  \
# 163    False          False          False      False     False        False
# 347     True          False          False      False     False         True
# 75      True          False          False      False     False        False
# 118    False          False          False      False     False        False
# 630    False          False          False      False     False        False
#
#      Possession  Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 163       False                   False                False           False
# 347       False                    True                False           False
# 75        False                   False                False           False
# 118       False                   False                False           False
# 630       False                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 163                   False        False          False            False
# 347                   False        False          False            False
# 75                    False        False          False            False
# 118                   False        False          False            False
# 630                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 163        False         False  False         False  False         False
# 347        False         False  False         False  False         False
# 75         False         False  False         False  False         False
# 118        False         False  False         False  False         False
# 630        False          True  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 163               False        False          False                 False
# 347               False        False          False                 False
# 75                False        False          False                 False
# 118               False        False          False                 False
# 630               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 163         True       False            False    False              False
# 347        False       False            False    False              False
# 75         False       False            False    False              False
# 118        False       False            False    False              False
# 630        False       False             True    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 163                 False         False       False      False
# 347                 False         False       False      False
# 75                  False         False       False      False
# 118                 False         False       False      False
# 630                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 163            False     False             True              False
# 347            False     False             True              False
# 75             False     False            False              False
# 118            False     False            False              False
# 630            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 163         False            False         False    False            False
# 347         False            False         False    False            False
# 75          False            False         False    False            False
# 118         False            False         False    False            False
# 630          True            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 163              False           False       False                False
# 347              False           False       False                False
# 75               False           False       False                False
# 118              False           False       False                False
# 630              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 163                         False                 False
# 347                         False                 False
# 75                          False                 False
# 118                         False                 False
# 630                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 163                  False          False      False         False
# 347                  False          False      False         False
# 75                   False          False      False         False
# 118                  False          False      False         False
# 630                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 163         False            False             False             False
# 347         False            False             False             False
# 75          False            False             False             False
# 118         False            False             False             False
# 630         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 163       False     False         False           False          False
# 347       False     False         False           False           True
# 75        False     False         False           False          False
# 118       False     False         False           False          False
# 630       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 163          False           False                   False            False
# 347          False            True                   False            False
# 75           False           False                   False            False
# 118          False           False                   False            False
# 630          False           False                   False             True
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 163       False    False       False       False                     False
# 347       False    False       False       False                     False
# 75        False    False       False       False                     False
# 118       False    False       False       False                     False
# 630       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 163            False         False          False         False       False
# 347            False          True          False         False       False
# 75             False         False          False         False       False
# 118            False         False          False         False       False
# 630             True         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 163                      False   False                False            False
# 347                      False   False                False            False
# 75                       False   False                False            False
# 118                      False   False                False            False
# 630                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 163            False        False           False      False           False
# 347             True        False            True      False           False
# 75             False        False           False      False           False
# 118            False        False           False      False           False
# 630            False        False           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 163              False         False       False     False           False
# 347              False         False       False     False           False
# 75               False         False       False     False           False
# 118              False         False       False     False           False
# 630              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 163         False       False          False               False
# 347         False       False          False               False
# 75          False       False          False               False
# 118         False       False          False               False
# 630         False       False           True               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 163                False                         False              False
# 347                False                         False              False
# 75                 False                         False              False
# 118                False                         False              False
# 630                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 163              False                 False                 False
# 347              False                 False                 False
# 75               False                 False                 False
# 118              False                 False                 False
# 630              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 163           False            False      False                    False
# 347           False            False      False                    False
# 75            False            False      False                    False
# 118           False            False      False                    False
# 630           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 163          False  False         False              False           False
# 347          False  False         False              False           False
# 75           False  False         False              False           False
# 118          False  False         False              False           False
# 630          False  False         False              False           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 163             False         False        False                 False
# 347             False         False         True                 False
# 75              False         False        False                 False
# 118             False         False        False                 False
# 630             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 163               False                 False    False         False
# 347               False                 False    False         False
# 75                False                 False    False         False
# 118               False                 False    False         False
# 630               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 163         False         False           False              False
# 347         False         False           False              False
# 75          False         False           False              False
# 118         False         False           False              False
# 630         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 163         False              False      False         False         False
# 347         False              False      False         False         False
# 75          False              False      False         False         False
# 118         False              False      False         False         False
# 630         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 163          False        False        False                False
# 347          False        False         True                False
# 75           False        False        False                False
# 118          False        False        False                False
# 630          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 163            False           False             False         False
# 347            False           False             False         False
# 75             False           False             False         False
# 118            False           False             False         False
# 630            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 163            False       False             False        False
# 347            False       False             False        False
# 75             False       False             False        False
# 118            False       False             False        False
# 630            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 163          False                  False          False        False
# 347          False                  False          False        False
# 75           False                  False          False        False
# 118          False                  False          False        False
# 630          False                  False          False        False
#
#      Omniscient  Power Count
# 163       False            2
# 347       False           18
# 75        False            1
# 118       False            2
# 630       False            8

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 655  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 656             Ymir    Male     white        Frost Giant           No Hair
# 657             Yoda    Male     brown     Yoda's species             White
# 658          Zatanna  Female      blue              Human             Black
# 659             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  Agility  \
# 0     203.0      Marvel Comics          -      good   441.0    False
# 1     191.0  Dark Horse Comics       blue      good    65.0     True
# 2     185.0          DC Comics        red      good    90.0    False
# 3     203.0      Marvel Comics          -       bad   441.0    False
# 5     193.0      Marvel Comics          -       bad   122.0    False
# ..      ...                ...        ...       ...     ...      ...
# 655   165.0      Marvel Comics          -      good    52.0    False
# 656   304.8      Marvel Comics      white      good   -99.0    False
# 657    66.0       George Lucas      green      good    17.0     True
# 658   170.0          DC Comics          -      good    57.0    False
# 659   185.0          DC Comics          -       bad    81.0    False
#
#      Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                   True               False                  False
# 1                   True               False                  False
# 2                  False                True                  False
# 3                   True               False                  False
# 5                  False               False                  False
# ..                   ...                 ...                    ...
# 655                False               False                  False
# 656                False               False                  False
# 657                False               False                  False
# 658                False               False                  False
# 659                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 1               True        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 5               True        True    False               True   False
# ..               ...         ...      ...                ...     ...
# 655            False       False    False              False    True
# 656             True        True    False              False   False
# 657            False       False     True              False   False
# 658            False       False    False              False   False
# 659            False       False    False              False   False
#
#      Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# 0           False                 False         False           False
# 1           False                  True          True            True
# 2           False                 False         False           False
# 3           False                 False         False           False
# 5           False                 False         False           False
# ..            ...                   ...           ...             ...
# 655         False                 False         False           False
# 656         False                 False         False           False
# 657          True                 False          True            True
# 658         False                 False         False           False
# 659         False                 False         False           False
#
#      Power Augmentation  Animal Attributes  Longevity  Intelligence  \
# 0                 False              False       True         False
# 1                 False              False       True          True
# 2                 False              False      False         False
# 3                 False              False      False          True
# 5                 False              False      False         False
# ..                  ...                ...        ...           ...
# 655               False              False      False         False
# 656               False              False       True         False
# 657               False              False       True          True
# 658               False              False      False         False
# 659               False              False      False         False
#
#      Super Strength  Cryokinesis  Telepathy  Energy Armor  Energy Blasts  \
# 0              True        False      False         False          False
# 1              True        False       True         False          False
# 2             False        False      False         False          False
# 3              True        False      False         False          False
# 5              True        False      False         False          False
# ..              ...          ...        ...           ...            ...
# 655           False        False      False         False           True
# 656            True         True      False         False          False
# 657           False        False       True         False           True
# 658           False         True       True         False          False
# 659           False        False      False         False          False
#
#      Duplication  Size Changing  Density Control  Stamina  Astral Travel  \
# 0          False          False            False     True          False
# 1          False          False            False     True          False
# 2          False          False            False    False          False
# 3          False          False            False     True          False
# 5          False          False            False    False          False
# ..           ...            ...              ...      ...            ...
# 655        False           True            False    False          False
# 656        False          False            False    False          False
# 657        False          False            False     True          False
# 658        False          False            False    False          False
# 659        False          False            False    False          False
#
#      Audio Control  Dexterity  Omnitrix  Super Speed  Possession  \
# 0            False      False     False        False       False
# 1            False      False     False        False       False
# 2            False      False     False        False       False
# 3            False      False     False         True       False
# 5            False      False     False        False       False
# ..             ...        ...       ...          ...         ...
# 655          False      False     False        False       False
# 656          False      False     False        False       False
# 657          False      False     False         True       False
# 658          False      False     False        False       False
# 659          False      False     False         True       False
#
#      Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0                     False                False           False
# 1                     False                False           False
# 2                     False                False           False
# 3                     False                False           False
# 5                     False                False           False
# ..                      ...                  ...             ...
# 655                   False                False           False
# 656                   False                False           False
# 657                   False                False           False
# 658                   False                False           False
# 659                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                     False        False          False            False
# 1                     False        False          False            False
# 2                     False        False          False            False
# 3                     False        False          False            False
# 5                     False        False          False            False
# ..                      ...          ...            ...              ...
# 655                   False        False          False            False
# 656                   False        False          False            False
# 657                   False        False          False            False
# 658                   False        False          False            False
# 659                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0          False         False  False         False  False         False
# 1          False         False  False         False  False         False
# 2          False         False  False         False  False         False
# 3          False         False  False         False  False         False
# 5          False         False  False         False  False         False
# ..           ...           ...    ...           ...    ...           ...
# 655        False         False  False         False  False         False
# 656        False         False  False         False  False         False
# 657         True         False  False         False   True         False
# 658        False         False   True         False  False         False
# 659        False         False  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0                 False        False          False                 False
# 1                 False        False          False                 False
# 2                 False        False          False                 False
# 3                 False        False          False                 False
# 5                 False        False          False                 False
# ..                  ...          ...            ...                   ...
# 655               False        False          False                 False
# 656               False        False          False                 False
# 657               False        False          False                 False
# 658               False        False          False                 False
# 659               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0          False        True            False    False              False
# 1           True       False            False    False              False
# 2          False       False            False    False              False
# 3          False       False            False    False              False
# 5          False       False            False    False              False
# ..           ...         ...              ...      ...                ...
# 655        False       False            False    False              False
# 656         True       False            False    False              False
# 657        False       False            False    False              False
# 658        False       False            False    False              False
# 659        False       False            False    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 0                   False         False       False      False
# 1                   False         False       False      False
# 2                   False         False       False      False
# 3                   False         False       False      False
# 5                   False         False       False      False
# ..                    ...           ...         ...        ...
# 655                 False         False       False      False
# 656                 False         False       False      False
# 657                 False         False       False      False
# 658                 False          True       False      False
# 659                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 0              False     False            False              False
# 1              False      True            False              False
# 2              False     False            False              False
# 3              False     False             True              False
# 5              False     False             True              False
# ..               ...       ...              ...                ...
# 655            False     False            False              False
# 656            False     False            False              False
# 657            False      True            False              False
# 658            False     False            False              False
# 659            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 0           False             True         False    False            False
# 1           False            False         False    False            False
# 2           False            False         False    False            False
# 3           False            False         False    False            False
# 5           False            False         False    False            False
# ..            ...              ...           ...      ...              ...
# 655         False            False         False    False            False
# 656         False            False         False    False            False
# 657          True            False         False     True            False
# 658         False            False         False    False            False
# 659         False            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 0                False           False       False                False
# 1                False           False       False                False
# 2                False           False       False                False
# 3                False           False       False                False
# 5                False           False       False                False
# ..                 ...             ...         ...                  ...
# 655              False           False       False                False
# 656              False           False       False                False
# 657              False           False       False                False
# 658              False           False       False                False
# 659              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 5                            True                 False
# ..                            ...                   ...
# 655                         False                 False
# 656                         False                 False
# 657                         False                 False
# 658                         False                 False
# 659                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 0                    False          False      False         False
# 1                    False          False      False         False
# 2                    False          False      False         False
# 3                    False          False       True         False
# 5                    False          False      False         False
# ..                     ...            ...        ...           ...
# 655                  False          False      False         False
# 656                  False          False      False         False
# 657                  False          False      False          True
# 658                  False          False      False         False
# 659                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 0           False            False             False             False
# 1           False            False             False             False
# 2           False            False             False             False
# 3           False            False             False             False
# 5           False             True             False             False
# ..            ...              ...               ...               ...
# 655         False            False             False             False
# 656         False            False             False             False
# 657         False            False             False             False
# 658         False            False             False             False
# 659         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 0         False     False         False           False          False
# 1         False     False         False           False          False
# 2         False     False         False           False          False
# 3         False     False         False           False          False
# 5         False     False         False           False           True
# ..          ...       ...           ...             ...            ...
# 655       False     False         False           False          False
# 656       False     False         False           False          False
# 657       False     False         False           False          False
# 658       False     False         False           False          False
# 659       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 0            False           False                   False            False
# 1            False            True                   False            False
# 2            False           False                   False            False
# 3            False           False                   False            False
# 5            False           False                    True            False
# ..             ...             ...                     ...              ...
# 655          False           False                   False            False
# 656          False           False                   False            False
# 657          False           False                   False            False
# 658          False           False                   False            False
# 659           True           False                   False            False
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 0         False    False       False       False                     False
# 1         False    False       False       False                     False
# 2         False    False       False       False                     False
# 3         False    False       False       False                     False
# 5         False    False       False       False                     False
# ..          ...      ...         ...         ...                       ...
# 655       False    False       False       False                     False
# 656       False    False       False       False                     False
# 657       False    False       False       False                     False
# 658       False    False       False       False                      True
# 659       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 0              False         False          False         False       False
# 1              False         False          False         False       False
# 2              False         False          False         False       False
# 3              False         False          False         False       False
# 5              False         False          False         False       False
# ..               ...           ...            ...           ...         ...
# 655            False         False          False         False       False
# 656            False         False          False         False       False
# 657            False         False          False         False       False
# 658            False         False          False         False       False
# 659            False         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 0                        False   False                False            False
# 1                        False   False                False            False
# 2                        False   False                False            False
# 3                        False   False                False            False
# 5                        False   False                False             True
# ..                         ...     ...                  ...              ...
# 655                      False   False                False            False
# 656                      False   False                False            False
# 657                      False   False                False            False
# 658                      False   False                False            False
# 659                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 0              False        False           False      False           False
# 1              False        False           False      False           False
# 2              False        False           False      False           False
# 3              False        False           False      False           False
# 5              False        False           False      False           False
# ..               ...          ...             ...        ...             ...
# 655            False        False           False      False           False
# 656            False        False           False      False           False
# 657            False        False           False      False           False
# 658            False        False           False      False           False
# 659            False         True           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 0                False         False       False     False           False
# 1                False         False       False     False           False
# 2                False         False       False     False           False
# 3                False         False       False     False           False
# 5                False         False       False     False           False
# ..                 ...           ...         ...       ...             ...
# 655              False         False       False     False           False
# 656              False         False       False     False           False
# 657              False         False       False      True           False
# 658              False         False       False     False           False
# 659              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 5           False       False          False               False
# ..            ...         ...            ...                 ...
# 655         False       False          False               False
# 656         False       False          False               False
# 657         False       False          False               False
# 658         False       False           True               False
# 659         False       False          False               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 0                  False                         False              False
# 1                  False                         False              False
# 2                  False                         False              False
# 3                  False                         False              False
# 5                  False                         False              False
# ..                   ...                           ...                ...
# 655                False                         False              False
# 656                False                         False              False
# 657                False                         False              False
# 658                False                         False              False
# 659                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 5                False                 False                 False
# ..                 ...                   ...                   ...
# 655              False                 False                 False
# 656              False                 False                 False
# 657              False                 False                 False
# 658              False                 False                 False
# 659              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 0             False            False      False                    False
# 1             False            False      False                    False
# 2             False            False      False                    False
# 3             False            False      False                    False
# 5             False            False      False                    False
# ..              ...              ...        ...                      ...
# 655           False            False      False                    False
# 656           False            False      False                    False
# 657           False            False      False                    False
# 658           False            False      False                    False
# 659           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 0            False  False         False              False           False
# 1            False  False         False              False           False
# 2            False  False         False              False           False
# 3            False  False         False              False           False
# 5            False  False         False              False           False
# ..             ...    ...           ...                ...             ...
# 655          False  False         False              False           False
# 656          False  False         False              False           False
# 657          False  False         False              False           False
# 658          False  False         False              False           False
# 659          False  False         False               True           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 0               False         False        False                 False
# 1               False         False         True                 False
# 2               False         False        False                 False
# 3               False         False        False                 False
# 5               False         False        False                 False
# ..                ...           ...          ...                   ...
# 655             False         False        False                 False
# 656             False         False        False                 False
# 657             False         False        False                 False
# 658             False         False        False                 False
# 659             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 0                 False                 False    False         False
# 1                 False                 False    False         False
# 2                 False                 False    False         False
# 3                 False                 False    False         False
# 5                 False                 False    False         False
# ..                  ...                   ...      ...           ...
# 655               False                 False    False         False
# 656               False                 False    False         False
# 657               False                 False    False         False
# 658               False                 False    False         False
# 659               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 0           False         False           False              False
# 1           False         False           False              False
# 2           False         False           False              False
# 3            True         False           False              False
# 5           False         False           False              False
# ..            ...           ...             ...                ...
# 655         False         False           False              False
# 656         False         False           False              False
# 657         False         False           False              False
# 658         False         False           False              False
# 659         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 0           False              False      False         False         False
# 1           False              False      False         False         False
# 2           False              False      False         False         False
# 3           False              False      False         False         False
# 5           False               True      False         False         False
# ..            ...                ...        ...           ...           ...
# 655         False              False      False         False         False
# 656         False              False      False         False         False
# 657         False              False       True         False         False
# 658         False              False      False         False          True
# 659         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 0            False        False        False                False
# 1            False        False        False                False
# 2            False        False        False                False
# 3            False        False        False                False
# 5            False        False        False                False
# ..             ...          ...          ...                  ...
# 655          False        False        False                False
# 656          False        False        False                False
# 657          False        False        False                False
# 658          False        False        False                False
# 659          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 0              False           False             False         False
# 1              False           False             False         False
# 2              False           False             False         False
# 3              False           False             False         False
# 5              False           False             False         False
# ..               ...             ...               ...           ...
# 655            False           False             False         False
# 656            False           False             False         False
# 657            False           False             False         False
# 658             True           False             False         False
# 659            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 5              False       False             False        False
# ..               ...         ...               ...          ...
# 655            False       False             False        False
# 656            False       False             False        False
# 657            False       False             False        False
# 658            False       False             False        False
# 659            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 5            False                  False          False        False
# ..             ...                    ...            ...          ...
# 655          False                  False          False        False
# 656          False                  False          False        False
# 657          False                  False          False        False
# 658          False                  False          False        False
# 659          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 5         False           11
# ..          ...          ...
# 655       False            3
# 656       False            6
# 657       False           19
# 658       False            8
# 659       False            4
#
# [490 rows x 178 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=question_2_df["Height"],
    y=question_2_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[(question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male"
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female"
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other"
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 655  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 656             Ymir    Male     white        Frost Giant           No Hair
# 657             Yoda    Male     brown     Yoda's species             White
# 658          Zatanna  Female      blue              Human             Black
# 659             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  Agility  \
# 0     203.0      Marvel Comics          -      good   441.0    False
# 1     191.0  Dark Horse Comics       blue      good    65.0     True
# 2     185.0          DC Comics        red      good    90.0    False
# 3     203.0      Marvel Comics          -       bad   441.0    False
# 4     -99.0      Marvel Comics          -       bad   -99.0    False
# ..      ...                ...        ...       ...     ...      ...
# 655   165.0      Marvel Comics          -      good    52.0    False
# 656   304.8      Marvel Comics      white      good   -99.0    False
# 657    66.0       George Lucas      green      good    17.0     True
# 658   170.0          DC Comics          -      good    57.0    False
# 659   185.0          DC Comics          -       bad    81.0    False
#
#      Accelerated Healing  Lantern Power Ring  Dimensional Awareness  \
# 0                   True               False                  False
# 1                   True               False                  False
# 2                  False                True                  False
# 3                   True               False                  False
# 4                  False               False                   True
# ..                   ...                 ...                    ...
# 655                False               False                  False
# 656                False               False                  False
# 657                False               False                  False
# 658                False               False                  False
# 659                False               False                  False
#
#      Cold Resistance  Durability  Stealth  Energy Absorption  Flight  \
# 0              False        True    False              False   False
# 1               True        True    False              False   False
# 2              False       False    False              False   False
# 3              False       False    False              False   False
# 4              False       False    False              False    True
# ..               ...         ...      ...                ...     ...
# 655            False       False    False              False    True
# 656             True        True    False              False   False
# 657            False       False     True              False   False
# 658            False       False    False              False   False
# 659            False       False    False              False   False
#
#      Danger Sense  Underwater breathing  Marksmanship  Weapons Master  \
# 0           False                 False         False           False
# 1           False                  True          True            True
# 2           False                 False         False           False
# 3           False                 False         False           False
# 4           False                 False         False           False
# ..            ...                   ...           ...             ...
# 655         False                 False         False           False
# 656         False                 False         False           False
# 657          True                 False          True            True
# 658         False                 False         False           False
# 659         False                 False         False           False
#
#      Power Augmentation  Animal Attributes  Longevity  Intelligence  \
# 0                 False              False       True         False
# 1                 False              False       True          True
# 2                 False              False      False         False
# 3                 False              False      False          True
# 4                 False              False      False          True
# ..                  ...                ...        ...           ...
# 655               False              False      False         False
# 656               False              False       True         False
# 657               False              False       True          True
# 658               False              False      False         False
# 659               False              False      False         False
#
#      Super Strength  Cryokinesis  Telepathy  Energy Armor  Energy Blasts  \
# 0              True        False      False         False          False
# 1              True        False       True         False          False
# 2             False        False      False         False          False
# 3              True        False      False         False          False
# 4              True        False      False         False          False
# ..              ...          ...        ...           ...            ...
# 655           False        False      False         False           True
# 656            True         True      False         False          False
# 657           False        False       True         False           True
# 658           False         True       True         False          False
# 659           False        False      False         False          False
#
#      Duplication  Size Changing  Density Control  Stamina  Astral Travel  \
# 0          False          False            False     True          False
# 1          False          False            False     True          False
# 2          False          False            False    False          False
# 3          False          False            False     True          False
# 4          False           True            False    False          False
# ..           ...            ...              ...      ...            ...
# 655        False           True            False    False          False
# 656        False          False            False    False          False
# 657        False          False            False     True          False
# 658        False          False            False    False          False
# 659        False          False            False    False          False
#
#      Audio Control  Dexterity  Omnitrix  Super Speed  Possession  \
# 0            False      False     False        False       False
# 1            False      False     False        False       False
# 2            False      False     False        False       False
# 3            False      False     False         True       False
# 4            False      False     False         True       False
# ..             ...        ...       ...          ...         ...
# 655          False      False     False        False       False
# 656          False      False     False        False       False
# 657          False      False     False         True       False
# 658          False      False     False        False       False
# 659          False      False     False         True       False
#
#      Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0                     False                False           False
# 1                     False                False           False
# 2                     False                False           False
# 3                     False                False           False
# 4                     False                False           False
# ..                      ...                  ...             ...
# 655                   False                False           False
# 656                   False                False           False
# 657                   False                False           False
# 658                   False                False           False
# 659                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                     False        False          False            False
# 1                     False        False          False            False
# 2                     False        False          False            False
# 3                     False        False          False            False
# 4                     False        False           True            False
# ..                      ...          ...            ...              ...
# 655                   False        False          False            False
# 656                   False        False          False            False
# 657                   False        False          False            False
# 658                   False        False          False            False
# 659                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0          False         False  False         False  False         False
# 1          False         False  False         False  False         False
# 2          False         False  False         False  False         False
# 3          False         False  False         False  False         False
# 4          False         False   True         False  False         False
# ..           ...           ...    ...           ...    ...           ...
# 655        False         False  False         False  False         False
# 656        False         False  False         False  False         False
# 657         True         False  False         False   True         False
# 658        False         False   True         False  False         False
# 659        False         False  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0                 False        False          False                 False
# 1                 False        False          False                 False
# 2                 False        False          False                 False
# 3                 False        False          False                 False
# 4                  True        False          False                 False
# ..                  ...          ...            ...                   ...
# 655               False        False          False                 False
# 656               False        False          False                 False
# 657               False        False          False                 False
# 658               False        False          False                 False
# 659               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0          False        True            False    False              False
# 1           True       False            False    False              False
# 2          False       False            False    False              False
# 3          False       False            False    False              False
# 4           True       False            False    False              False
# ..           ...         ...              ...      ...                ...
# 655        False       False            False    False              False
# 656         True       False            False    False              False
# 657        False       False            False    False              False
# 658        False       False            False    False              False
# 659        False       False            False    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 0                   False         False       False      False
# 1                   False         False       False      False
# 2                   False         False       False      False
# 3                   False         False       False      False
# 4                   False         False       False      False
# ..                    ...           ...         ...        ...
# 655                 False         False       False      False
# 656                 False         False       False      False
# 657                 False         False       False      False
# 658                 False          True       False      False
# 659                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 0              False     False            False              False
# 1              False      True            False              False
# 2              False     False            False              False
# 3              False     False             True              False
# 4              False     False             True              False
# ..               ...       ...              ...                ...
# 655            False     False            False              False
# 656            False     False            False              False
# 657            False      True            False              False
# 658            False     False            False              False
# 659            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 0           False             True         False    False            False
# 1           False            False         False    False            False
# 2           False            False         False    False            False
# 3           False            False         False    False            False
# 4           False            False         False    False            False
# ..            ...              ...           ...      ...              ...
# 655         False            False         False    False            False
# 656         False            False         False    False            False
# 657          True            False         False     True            False
# 658         False            False         False    False            False
# 659         False            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 0                False           False       False                False
# 1                False           False       False                False
# 2                False           False       False                False
# 3                False           False       False                False
# 4                False           False       False                False
# ..                 ...             ...         ...                  ...
# 655              False           False       False                False
# 656              False           False       False                False
# 657              False           False       False                False
# 658              False           False       False                False
# 659              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
# ..                            ...                   ...
# 655                         False                 False
# 656                         False                 False
# 657                         False                 False
# 658                         False                 False
# 659                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 0                    False          False      False         False
# 1                    False          False      False         False
# 2                    False          False      False         False
# 3                    False          False       True         False
# 4                    False          False      False         False
# ..                     ...            ...        ...           ...
# 655                  False          False      False         False
# 656                  False          False      False         False
# 657                  False          False      False          True
# 658                  False          False      False         False
# 659                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 0           False            False             False             False
# 1           False            False             False             False
# 2           False            False             False             False
# 3           False            False             False             False
# 4           False            False             False             False
# ..            ...              ...               ...               ...
# 655         False            False             False             False
# 656         False            False             False             False
# 657         False            False             False             False
# 658         False            False             False             False
# 659         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 0         False     False         False           False          False
# 1         False     False         False           False          False
# 2         False     False         False           False          False
# 3         False     False         False           False          False
# 4         False     False         False           False          False
# ..          ...       ...           ...             ...            ...
# 655       False     False         False           False          False
# 656       False     False         False           False          False
# 657       False     False         False           False          False
# 658       False     False         False           False          False
# 659       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 0            False           False                   False            False
# 1            False            True                   False            False
# 2            False           False                   False            False
# 3            False           False                   False            False
# 4            False           False                    True            False
# ..             ...             ...                     ...              ...
# 655          False           False                   False            False
# 656          False           False                   False            False
# 657          False           False                   False            False
# 658          False           False                   False            False
# 659           True           False                   False            False
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 0         False    False       False       False                     False
# 1         False    False       False       False                     False
# 2         False    False       False       False                     False
# 3         False    False       False       False                     False
# 4         False    False       False       False                     False
# ..          ...      ...         ...         ...                       ...
# 655       False    False       False       False                     False
# 656       False    False       False       False                     False
# 657       False    False       False       False                     False
# 658       False    False       False       False                      True
# 659       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 0              False         False          False         False       False
# 1              False         False          False         False       False
# 2              False         False          False         False       False
# 3              False         False          False         False       False
# 4              False         False          False         False       False
# ..               ...           ...            ...           ...         ...
# 655            False         False          False         False       False
# 656            False         False          False         False       False
# 657            False         False          False         False       False
# 658            False         False          False         False       False
# 659            False         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 0                        False   False                False            False
# 1                        False   False                False            False
# 2                        False   False                False            False
# 3                        False   False                False            False
# 4                        False   False                 True            False
# ..                         ...     ...                  ...              ...
# 655                      False   False                False            False
# 656                      False   False                False            False
# 657                      False   False                False            False
# 658                      False   False                False            False
# 659                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 0              False        False           False      False           False
# 1              False        False           False      False           False
# 2              False        False           False      False           False
# 3              False        False           False      False           False
# 4              False        False           False      False           False
# ..               ...          ...             ...        ...             ...
# 655            False        False           False      False           False
# 656            False        False           False      False           False
# 657            False        False           False      False           False
# 658            False        False           False      False           False
# 659            False         True           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 0                False         False       False     False           False
# 1                False         False       False     False           False
# 2                False         False       False     False           False
# 3                False         False       False     False           False
# 4                False         False       False     False           False
# ..                 ...           ...         ...       ...             ...
# 655              False         False       False     False           False
# 656              False         False       False     False           False
# 657              False         False       False      True           False
# 658              False         False       False     False           False
# 659              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4            True       False          False               False
# ..            ...         ...            ...                 ...
# 655         False       False          False               False
# 656         False       False          False               False
# 657         False       False          False               False
# 658         False       False           True               False
# 659         False       False          False               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 0                  False                         False              False
# 1                  False                         False              False
# 2                  False                         False              False
# 3                  False                         False              False
# 4                  False                         False              False
# ..                   ...                           ...                ...
# 655                False                         False              False
# 656                False                         False              False
# 657                False                         False              False
# 658                False                         False              False
# 659                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
# ..                 ...                   ...                   ...
# 655              False                 False                 False
# 656              False                 False                 False
# 657              False                 False                 False
# 658              False                 False                 False
# 659              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 0             False            False      False                    False
# 1             False            False      False                    False
# 2             False            False      False                    False
# 3             False            False      False                    False
# 4             False            False      False                    False
# ..              ...              ...        ...                      ...
# 655           False            False      False                    False
# 656           False            False      False                    False
# 657           False            False      False                    False
# 658           False            False      False                    False
# 659           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 0            False  False         False              False           False
# 1            False  False         False              False           False
# 2            False  False         False              False           False
# 3            False  False         False              False           False
# 4            False  False         False              False           False
# ..             ...    ...           ...                ...             ...
# 655          False  False         False              False           False
# 656          False  False         False              False           False
# 657          False  False         False              False           False
# 658          False  False         False              False           False
# 659          False  False         False               True           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 0               False         False        False                 False
# 1               False         False         True                 False
# 2               False         False        False                 False
# 3               False         False        False                 False
# 4               False         False        False                 False
# ..                ...           ...          ...                   ...
# 655             False         False        False                 False
# 656             False         False        False                 False
# 657             False         False        False                 False
# 658             False         False        False                 False
# 659             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 0                 False                 False    False         False
# 1                 False                 False    False         False
# 2                 False                 False    False         False
# 3                 False                 False    False         False
# 4                 False                 False    False         False
# ..                  ...                   ...      ...           ...
# 655               False                 False    False         False
# 656               False                 False    False         False
# 657               False                 False    False         False
# 658               False                 False    False         False
# 659               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 0           False         False           False              False
# 1           False         False           False              False
# 2           False         False           False              False
# 3            True         False           False              False
# 4           False         False           False              False
# ..            ...           ...             ...                ...
# 655         False         False           False              False
# 656         False         False           False              False
# 657         False         False           False              False
# 658         False         False           False              False
# 659         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 0           False              False      False         False         False
# 1           False              False      False         False         False
# 2           False              False      False         False         False
# 3           False              False      False         False         False
# 4           False              False      False         False         False
# ..            ...                ...        ...           ...           ...
# 655         False              False      False         False         False
# 656         False              False      False         False         False
# 657         False              False       True         False         False
# 658         False              False      False         False          True
# 659         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 0            False        False        False                False
# 1            False        False        False                False
# 2            False        False        False                False
# 3            False        False        False                False
# 4            False        False        False                False
# ..             ...          ...          ...                  ...
# 655          False        False        False                False
# 656          False        False        False                False
# 657          False        False        False                False
# 658          False        False        False                False
# 659          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 0              False           False             False         False
# 1              False           False             False         False
# 2              False           False             False         False
# 3              False           False             False         False
# 4              False           False             False         False
# ..               ...             ...               ...           ...
# 655            False           False             False         False
# 656            False           False             False         False
# 657            False           False             False         False
# 658             True           False             False         False
# 659            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 655            False       False             False        False
# 656            False       False             False        False
# 657            False       False             False        False
# 658            False       False             False        False
# 659            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 655          False                  False          False        False
# 656          False                  False          False        False
# 657          False                  False          False        False
# 658          False                  False          False        False
# 659          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# ..          ...          ...
# 655       False            3
# 656       False            6
# 657       False           19
# 658       False            8
# 659       False            4
#
# [660 rows x 178 columns]

# %%
heroes_and_powers_df1 = heroes_and_powers_df.drop(columns=['name','Gender', 'Eye color','Race','Hair color','Height','Skin color','Alignment','Weight','Power Count'])
heroes_and_powers_df1
# Out:
#              Publisher  Agility  Accelerated Healing  Lantern Power Ring  \
# 0        Marvel Comics    False                 True               False
# 1    Dark Horse Comics     True                 True               False
# 2            DC Comics    False                False                True
# 3        Marvel Comics    False                 True               False
# 4        Marvel Comics    False                False               False
# ..                 ...      ...                  ...                 ...
# 655      Marvel Comics    False                False               False
# 656      Marvel Comics    False                False               False
# 657       George Lucas     True                False               False
# 658          DC Comics    False                False               False
# 659          DC Comics    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                    False            False        True    False
# 1                    False             True        True    False
# 2                    False            False       False    False
# 3                    False            False       False    False
# 4                     True            False       False    False
# ..                     ...              ...         ...      ...
# 655                  False            False       False    False
# 656                  False             True        True    False
# 657                  False            False       False     True
# 658                  False            False       False    False
# 659                  False            False       False    False
#
#      Energy Absorption  Flight  Danger Sense  Underwater breathing  \
# 0                False   False         False                 False
# 1                False   False         False                  True
# 2                False   False         False                 False
# 3                False   False         False                 False
# 4                False    True         False                 False
# ..                 ...     ...           ...                   ...
# 655              False    True         False                 False
# 656              False   False         False                 False
# 657              False   False          True                 False
# 658              False   False         False                 False
# 659              False   False         False                 False
#
#      Marksmanship  Weapons Master  Power Augmentation  Animal Attributes  \
# 0           False           False               False              False
# 1            True            True               False              False
# 2           False           False               False              False
# 3           False           False               False              False
# 4           False           False               False              False
# ..            ...             ...                 ...                ...
# 655         False           False               False              False
# 656         False           False               False              False
# 657          True            True               False              False
# 658         False           False               False              False
# 659         False           False               False              False
#
#      Longevity  Intelligence  Super Strength  Cryokinesis  Telepathy  \
# 0         True         False            True        False      False
# 1         True          True            True        False       True
# 2        False         False           False        False      False
# 3        False          True            True        False      False
# 4        False          True            True        False      False
# ..         ...           ...             ...          ...        ...
# 655      False         False           False        False      False
# 656       True         False            True         True      False
# 657       True          True           False        False       True
# 658      False         False           False         True       True
# 659      False         False           False        False      False
#
#      Energy Armor  Energy Blasts  Duplication  Size Changing  Density Control  \
# 0           False          False        False          False            False
# 1           False          False        False          False            False
# 2           False          False        False          False            False
# 3           False          False        False          False            False
# 4           False          False        False           True            False
# ..            ...            ...          ...            ...              ...
# 655         False           True        False           True            False
# 656         False          False        False          False            False
# 657         False           True        False          False            False
# 658         False          False        False          False            False
# 659         False          False        False          False            False
#
#      Stamina  Astral Travel  Audio Control  Dexterity  Omnitrix  Super Speed  \
# 0       True          False          False      False     False        False
# 1       True          False          False      False     False        False
# 2      False          False          False      False     False        False
# 3       True          False          False      False     False         True
# 4      False          False          False      False     False         True
# ..       ...            ...            ...        ...       ...          ...
# 655    False          False          False      False     False        False
# 656    False          False          False      False     False        False
# 657     True          False          False      False     False         True
# 658    False          False          False      False     False        False
# 659    False          False          False      False     False         True
#
#      Possession  Animal Oriented Powers  Weapon-based Powers  Electrokinesis  \
# 0         False                   False                False           False
# 1         False                   False                False           False
# 2         False                   False                False           False
# 3         False                   False                False           False
# 4         False                   False                False           False
# ..          ...                     ...                  ...             ...
# 655       False                   False                False           False
# 656       False                   False                False           False
# 657       False                   False                False           False
# 658       False                   False                False           False
# 659       False                   False                False           False
#
#      Darkforce Manipulation  Death Touch  Teleportation  Enhanced Senses  \
# 0                     False        False          False            False
# 1                     False        False          False            False
# 2                     False        False          False            False
# 3                     False        False          False            False
# 4                     False        False           True            False
# ..                      ...          ...            ...              ...
# 655                   False        False          False            False
# 656                   False        False          False            False
# 657                   False        False          False            False
# 658                   False        False          False            False
# 659                   False        False          False            False
#
#      Telekinesis  Energy Beams  Magic  Hyperkinesis   Jump  Clairvoyance  \
# 0          False         False  False         False  False         False
# 1          False         False  False         False  False         False
# 2          False         False  False         False  False         False
# 3          False         False  False         False  False         False
# 4          False         False   True         False  False         False
# ..           ...           ...    ...           ...    ...           ...
# 655        False         False  False         False  False         False
# 656        False         False  False         False  False         False
# 657         True         False  False         False   True         False
# 658        False         False   True         False  False         False
# 659        False         False  False         False  False         False
#
#      Dimensional Travel  Power Sense  Shapeshifting  Peak Human Condition  \
# 0                 False        False          False                 False
# 1                 False        False          False                 False
# 2                 False        False          False                 False
# 3                 False        False          False                 False
# 4                  True        False          False                 False
# ..                  ...          ...            ...                   ...
# 655               False        False          False                 False
# 656               False        False          False                 False
# 657               False        False          False                 False
# 658               False        False          False                 False
# 659               False        False          False                 False
#
#      Immortality  Camouflage  Element Control  Phasing  Astral Projection  \
# 0          False        True            False    False              False
# 1           True       False            False    False              False
# 2          False       False            False    False              False
# 3          False       False            False    False              False
# 4           True       False            False    False              False
# ..           ...         ...              ...      ...                ...
# 655        False       False            False    False              False
# 656         True       False            False    False              False
# 657        False       False            False    False              False
# 658        False       False            False    False              False
# 659        False       False            False    False              False
#
#      Electrical Transport  Fire Control  Projection  Summoning  \
# 0                   False         False       False      False
# 1                   False         False       False      False
# 2                   False         False       False      False
# 3                   False         False       False      False
# 4                   False         False       False      False
# ..                    ...           ...         ...        ...
# 655                 False         False       False      False
# 656                 False         False       False      False
# 657                 False         False       False      False
# 658                 False          True       False      False
# 659                 False         False       False      False
#
#      Enhanced Memory  Reflexes  Invulnerability  Energy Constructs  \
# 0              False     False            False              False
# 1              False      True            False              False
# 2              False     False            False              False
# 3              False     False             True              False
# 4              False     False             True              False
# ..               ...       ...              ...                ...
# 655            False     False            False              False
# 656            False     False            False              False
# 657            False      True            False              False
# 658            False     False            False              False
# 659            False     False            False              False
#
#      Force Fields  Self-Sustenance  Anti-Gravity  Empathy  Power Nullifier  \
# 0           False             True         False    False            False
# 1           False            False         False    False            False
# 2           False            False         False    False            False
# 3           False            False         False    False            False
# 4           False            False         False    False            False
# ..            ...              ...           ...      ...              ...
# 655         False            False         False    False            False
# 656         False            False         False    False            False
# 657          True            False         False     True            False
# 658         False            False         False    False            False
# 659         False            False         False    False            False
#
#      Radiation Control  Psionic Powers  Elasticity  Substance Secretion  \
# 0                False           False       False                False
# 1                False           False       False                False
# 2                False           False       False                False
# 3                False           False       False                False
# 4                False           False       False                False
# ..                 ...             ...         ...                  ...
# 655              False           False       False                False
# 656              False           False       False                False
# 657              False           False       False                False
# 658              False           False       False                False
# 659              False           False       False                False
#
#      Elemental Transmogrification  Technopath/Cyberpath  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                 False
# 4                           False                 False
# ..                            ...                   ...
# 655                         False                 False
# 656                         False                 False
# 657                         False                 False
# 658                         False                 False
# 659                         False                 False
#
#      Photographic Reflexes  Seismic Power  Animation  Precognition  \
# 0                    False          False      False         False
# 1                    False          False      False         False
# 2                    False          False      False         False
# 3                    False          False       True         False
# 4                    False          False      False         False
# ..                     ...            ...        ...           ...
# 655                  False          False      False         False
# 656                  False          False      False         False
# 657                  False          False      False          True
# 658                  False          False      False         False
# 659                  False          False      False         False
#
#      Mind Control  Fire Resistance  Power Absorption  Enhanced Hearing  \
# 0           False            False             False             False
# 1           False            False             False             False
# 2           False            False             False             False
# 3           False            False             False             False
# 4           False            False             False             False
# ..            ...              ...               ...               ...
# 655         False            False             False             False
# 656         False            False             False             False
# 657         False            False             False             False
# 658         False            False             False             False
# 659         False            False             False             False
#
#      Nova Force  Insanity  Hypnokinesis  Animal Control  Natural Armor  \
# 0         False     False         False           False          False
# 1         False     False         False           False          False
# 2         False     False         False           False          False
# 3         False     False         False           False          False
# 4         False     False         False           False          False
# ..          ...       ...           ...             ...            ...
# 655       False     False         False           False          False
# 656       False     False         False           False          False
# 657       False     False         False           False          False
# 658       False     False         False           False          False
# 659       False     False         False           False          False
#
#      Intangibility  Enhanced Sight  Molecular Manipulation  Heat Generation  \
# 0            False           False                   False            False
# 1            False            True                   False            False
# 2            False           False                   False            False
# 3            False           False                   False            False
# 4            False           False                    True            False
# ..             ...             ...                     ...              ...
# 655          False           False                   False            False
# 656          False           False                   False            False
# 657          False           False                   False            False
# 658          False           False                   False            False
# 659           True           False                   False            False
#
#      Adaptation  Gliding  Power Suit  Mind Blast  Probability Manipulation  \
# 0         False    False       False       False                     False
# 1         False    False       False       False                     False
# 2         False    False       False       False                     False
# 3         False    False       False       False                     False
# 4         False    False       False       False                     False
# ..          ...      ...         ...         ...                       ...
# 655       False    False       False       False                     False
# 656       False    False       False       False                     False
# 657       False    False       False       False                     False
# 658       False    False       False       False                      True
# 659       False    False       False       False                     False
#
#      Gravity Control  Regeneration  Light Control  Echolocation  Levitation  \
# 0              False         False          False         False       False
# 1              False         False          False         False       False
# 2              False         False          False         False       False
# 3              False         False          False         False       False
# 4              False         False          False         False       False
# ..               ...           ...            ...           ...         ...
# 655            False         False          False         False       False
# 656            False         False          False         False       False
# 657            False         False          False         False       False
# 658            False         False          False         False       False
# 659            False         False          False         False       False
#
#      Toxin and Disease Control  Banish  Energy Manipulation  Heat Resistance  \
# 0                        False   False                False            False
# 1                        False   False                False            False
# 2                        False   False                False            False
# 3                        False   False                False            False
# 4                        False   False                 True            False
# ..                         ...     ...                  ...              ...
# 655                      False   False                False            False
# 656                      False   False                False            False
# 657                      False   False                False            False
# 658                      False   False                False            False
# 659                      False   False                False            False
#
#      Natural Weapons  Time Travel  Enhanced Smell  Illusions  Thirstokinesis  \
# 0              False        False           False      False           False
# 1              False        False           False      False           False
# 2              False        False           False      False           False
# 3              False        False           False      False           False
# 4              False        False           False      False           False
# ..               ...          ...             ...        ...             ...
# 655            False        False           False      False           False
# 656            False        False           False      False           False
# 657            False        False           False      False           False
# 658            False        False           False      False           False
# 659            False         True           False      False           False
#
#      Hair Manipulation  Illumination  Omnipotent  Cloaking  Changing Armor  \
# 0                False         False       False     False           False
# 1                False         False       False     False           False
# 2                False         False       False     False           False
# 3                False         False       False     False           False
# 4                False         False       False     False           False
# ..                 ...           ...         ...       ...             ...
# 655              False         False       False     False           False
# 656              False         False       False     False           False
# 657              False         False       False      True           False
# 658              False         False       False     False           False
# 659              False         False       False     False           False
#
#      Power Cosmic  Biokinesis  Water Control  Radiation Immunity  \
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4            True       False          False               False
# ..            ...         ...            ...                 ...
# 655         False       False          False               False
# 656         False       False          False               False
# 657         False       False          False               False
# 658         False       False           True               False
# 659         False       False          False               False
#
#      Vision - Telescopic  Toxin and Disease Resistance  Spatial Awareness  \
# 0                  False                         False              False
# 1                  False                         False              False
# 2                  False                         False              False
# 3                  False                         False              False
# 4                  False                         False              False
# ..                   ...                           ...                ...
# 655                False                         False              False
# 656                False                         False              False
# 657                False                         False              False
# 658                False                         False              False
# 659                False                         False              False
#
#      Energy Resistance  Telepathy Resistance  Molecular Combustion  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
# ..                 ...                   ...                   ...
# 655              False                 False                 False
# 656              False                 False                 False
# 657              False                 False                 False
# 658              False                 False                 False
# 659              False                 False                 False
#
#      Omnilingualism  Portal Creation  Magnetism  Mind Control Resistance  \
# 0             False            False      False                    False
# 1             False            False      False                    False
# 2             False            False      False                    False
# 3             False            False      False                    False
# 4             False            False      False                    False
# ..              ...              ...        ...                      ...
# 655           False            False      False                    False
# 656           False            False      False                    False
# 657           False            False      False                    False
# 658           False            False      False                    False
# 659           False            False      False                    False
#
#      Plant Control  Sonar  Sonic Scream  Time Manipulation  Enhanced Touch  \
# 0            False  False         False              False           False
# 1            False  False         False              False           False
# 2            False  False         False              False           False
# 3            False  False         False              False           False
# 4            False  False         False              False           False
# ..             ...    ...           ...                ...             ...
# 655          False  False         False              False           False
# 656          False  False         False              False           False
# 657          False  False         False              False           False
# 658          False  False         False              False           False
# 659          False  False         False               True           False
#
#      Magic Resistance  Invisibility  Sub-Mariner  Radiation Absorption  \
# 0               False         False        False                 False
# 1               False         False         True                 False
# 2               False         False        False                 False
# 3               False         False        False                 False
# 4               False         False        False                 False
# ..                ...           ...          ...                   ...
# 655             False         False        False                 False
# 656             False         False        False                 False
# 657             False         False        False                 False
# 658             False         False        False                 False
# 659             False         False        False                 False
#
#      Intuitive aptitude  Vision - Microscopic  Melting  Wind Control  \
# 0                 False                 False    False         False
# 1                 False                 False    False         False
# 2                 False                 False    False         False
# 3                 False                 False    False         False
# 4                 False                 False    False         False
# ..                  ...                   ...      ...           ...
# 655               False                 False    False         False
# 656               False                 False    False         False
# 657               False                 False    False         False
# 658               False                 False    False         False
# 659               False                 False    False         False
#
#      Super Breath  Wallcrawling  Vision - Night  Vision - Infrared  \
# 0           False         False           False              False
# 1           False         False           False              False
# 2           False         False           False              False
# 3            True         False           False              False
# 4           False         False           False              False
# ..            ...           ...             ...                ...
# 655         False         False           False              False
# 656         False         False           False              False
# 657         False         False           False              False
# 658         False         False           False              False
# 659         False         False           False              False
#
#      Grim Reaping  Matter Absorption  The Force  Resurrection  Terrakinesis  \
# 0           False              False      False         False         False
# 1           False              False      False         False         False
# 2           False              False      False         False         False
# 3           False              False      False         False         False
# 4           False              False      False         False         False
# ..            ...                ...        ...           ...           ...
# 655         False              False      False         False         False
# 656         False              False      False         False         False
# 657         False              False       True         False         False
# 658         False              False      False         False          True
# 659         False              False      False         False         False
#
#      Vision - Heat  Vitakinesis  Radar Sense  Qwardian Power Ring  \
# 0            False        False        False                False
# 1            False        False        False                False
# 2            False        False        False                False
# 3            False        False        False                False
# 4            False        False        False                False
# ..             ...          ...          ...                  ...
# 655          False        False        False                False
# 656          False        False        False                False
# 657          False        False        False                False
# 658          False        False        False                False
# 659          False        False        False                False
#
#      Weather Control  Vision - X-Ray  Vision - Thermal  Web Creation  \
# 0              False           False             False         False
# 1              False           False             False         False
# 2              False           False             False         False
# 3              False           False             False         False
# 4              False           False             False         False
# ..               ...             ...               ...           ...
# 655            False           False             False         False
# 656            False           False             False         False
# 657            False           False             False         False
# 658             True           False             False         False
# 659            False           False             False         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# ..               ...         ...               ...          ...
# 655            False       False             False        False
# 656            False       False             False        False
# 657            False       False             False        False
# 658            False       False             False        False
# 659            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# ..             ...                    ...            ...          ...
# 655          False                  False          False        False
# 656          False                  False          False        False
# 657          False                  False          False        False
# 658          False                  False          False        False
# 659          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 655       False
# 656       False
# 657       False
# 658       False
# 659       False
#
# [660 rows x 168 columns]

# %%
#heroes_and_powers_df1.groupby(['Publisher']).sum().T
heroes_and_powers_df1.where(heroes_and_powers_df1['Publisher'].isin(['Marvel Comics','DC Comics'])).groupby('Publisher').sum().T
# Out:
# Publisher              DC Comics  Marvel Comics
# Agility                     71.0          134.0
# Accelerated Healing         51.0          100.0
# Lantern Power Ring          11.0            0.0
# Dimensional Awareness        7.0           16.0
# Cold Resistance             15.0           25.0
# ...                          ...            ...
# Phoenix Force                0.0            1.0
# Molecular Dissipation        1.0            0.0
# Vision - Cryo                1.0            0.0
# Omnipresent                  0.0            1.0
# Omniscient                   0.0            1.0
#
# [167 rows x 2 columns]

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-309-8d8338c8bb42> in <module>
#       2
#       3 # Checking that you made a dataframe called question_3_df
# ----> 4 assert type(question_3_df) == pd.DataFrame
#       5
#       6 # Checking the shape
#
# AssertionError:

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
marvel_most_common
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-310-20e687b5c287> in <module>
#       1 # Run this cell without changes
#       2
# ----> 3 marvel_most_common = question_3_df.drop("DC Comics", axis=1)
#       4 marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
#       5 marvel_most_common
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4495         dtype: float64
#    4496         """
# -> 4497         return super().drop(
#    4498             labels=labels,
#    4499             axis=axis,
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3872             if index is not None or columns is not None:
#    3873                 raise ValueError("Cannot specify both 'labels' and 'index'/'columns'")
# -> 3874             axis_name = self._get_axis_name(axis)
#    3875             axes = {axis_name: labels}
#    3876         elif index is not None or columns is not None:
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _get_axis_name(cls, axis)
#     372     @classmethod
#     373     def _get_axis_name(cls, axis: Axis) -> str:
# --> 374         axis_number = cls._get_axis_number(axis)
#     375         return cls._AXIS_ORDERS[axis_number]
#     376
#
# ~\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named 1 for object type Series

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"],
    height=marvel_most_common["Marvel Comics"]
)
ax2.bar(
    x=dc_most_common["Superpower Name"],
    height=dc_most_common["DC Comics"]
)

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
None
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
